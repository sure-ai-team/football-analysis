# %%
import os
os.environ["ONNXRUNTIME_EXECUTION_PROVIDERS"] = "[CUDAExecutionProvider]"

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /home/ubuntu/projects/sure-football-analysis

# %%
# from inference import get_model
from ultralytics import YOLO

# ROBOFLOW_API_KEY = os.environ.get("ROBOFLOW_API_KEY")
# PLAYER_DETECTION_MODEL_ID = "football-players-detection-3zvbc/12"
# PLAYER_DETECTION_MODEL = get_model(PLAYER_DETECTION_MODEL_ID, api_key=ROBOFLOW_API_KEY)
PLAYER_DETECTION_MODEL = YOLO("app/models/yolo11_football_v2/weights/best.pt")

# %%
import torch
from transformers import AutoProcessor, SiglipVisionModel

SIGLIP_MODEL_PATH = 'google/siglip-base-patch16-224'

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
EMBEDDINGS_MODEL = SiglipVisionModel.from_pretrained(SIGLIP_MODEL_PATH).to(DEVICE)
EMBEDDINGS_PROCESSOR = AutoProcessor.from_pretrained(SIGLIP_MODEL_PATH)

# %%
import supervision as sv
import numpy as np
from more_itertools import chunked
from tqdm import tqdm

SOURCE_VIDEO_PATH = "app/test_data/raw/121364_0.mp4"
BATCH_SIZE = 32
PLAYER_ID = 2
STRIDE = 30

frame_generator = sv.get_video_frames_generator(
    source_path=SOURCE_VIDEO_PATH, stride=STRIDE)

crops = []
for frame in tqdm(frame_generator, desc='collecting crops'):
    # result = PLAYER_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
    result = PLAYER_DETECTION_MODEL.predict(frame, conf=0.3)[0]
    # detections = sv.Detections.from_inference(result)
    detections = sv.Detections.from_ultralytics(result)
    detections = detections.with_nms(threshold=0.5, class_agnostic=True)
    detections = detections[detections.class_id == PLAYER_ID]
    players_crops = [sv.crop_image(frame, xyxy) for xyxy in detections.xyxy]
    crops += players_crops


crops = [sv.cv2_to_pillow(crop) for crop in crops]
batches = chunked(crops, BATCH_SIZE)
data = []
with torch.no_grad():
    for batch in tqdm(batches, desc='embedding extraction'):
        inputs = EMBEDDINGS_PROCESSOR(images=batch, return_tensors="pt").to(DEVICE)
        outputs = EMBEDDINGS_MODEL(**inputs)
        embeddings = torch.mean(outputs.last_hidden_state, dim=1).cpu().numpy()
        data.append(embeddings)

data = np.concatenate(data)
# Out:
# collecting crops: 0it [00:00, ?it/s]
# 0: 736x1280 1 ball, 2 goalkeepers, 20 players, 2 referees, 77.8ms
# Speed: 17.0ms preprocess, 77.8ms inference, 235.5ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 1it [00:02,  2.16s/it]
# 0: 736x1280 1 goalkeeper, 20 players, 2 referees, 32.3ms
# Speed: 10.2ms preprocess, 32.3ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 2it [00:02,  1.03it/s]
# 0: 736x1280 1 goalkeeper, 21 players, 2 referees, 32.5ms
# Speed: 6.9ms preprocess, 32.5ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 3it [00:02,  1.70it/s]
# 0: 736x1280 20 players, 2 referees, 32.5ms
# Speed: 8.8ms preprocess, 32.5ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 4it [00:02,  2.47it/s]
# 0: 736x1280 1 ball, 20 players, 2 referees, 32.6ms
# Speed: 10.8ms preprocess, 32.6ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 5it [00:02,  3.22it/s]
# 0: 736x1280 1 ball, 20 players, 2 referees, 33.0ms
# Speed: 10.5ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 6it [00:02,  4.02it/s]
# 0: 736x1280 20 players, 2 referees, 32.8ms
# Speed: 8.1ms preprocess, 32.8ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 7it [00:02,  4.72it/s]
# 0: 736x1280 1 ball, 19 players, 2 referees, 32.5ms
# Speed: 10.0ms preprocess, 32.5ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 8it [00:03,  5.42it/s]
# 0: 736x1280 1 ball, 1 goalkeeper, 20 players, 2 referees, 32.9ms
# Speed: 7.0ms preprocess, 32.9ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 9it [00:03,  5.96it/s]
# 0: 736x1280 1 ball, 21 players, 2 referees, 33.0ms
# Speed: 7.3ms preprocess, 33.0ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 10it [00:03,  6.22it/s]
# 0: 736x1280 1 ball, 22 players, 2 referees, 33.2ms
# Speed: 9.9ms preprocess, 33.2ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 11it [00:03,  6.50it/s]
# 0: 736x1280 1 ball, 1 goalkeeper, 20 players, 2 referees, 33.0ms
# Speed: 7.1ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 12it [00:03,  6.68it/s]
# 0: 736x1280 1 goalkeeper, 21 players, 2 referees, 32.4ms
# Speed: 10.3ms preprocess, 32.4ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 13it [00:03,  6.96it/s]
# 0: 736x1280 1 ball, 1 goalkeeper, 20 players, 2 referees, 32.4ms
# Speed: 7.0ms preprocess, 32.4ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 14it [00:03,  7.04it/s]
# 0: 736x1280 1 goalkeeper, 21 players, 2 referees, 32.6ms
# Speed: 11.1ms preprocess, 32.6ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 15it [00:04,  7.10it/s]
# 0: 736x1280 1 goalkeeper, 21 players, 2 referees, 32.4ms
# Speed: 11.2ms preprocess, 32.4ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 16it [00:04,  7.04it/s]
# 0: 736x1280 20 players, 3 referees, 32.8ms
# Speed: 9.8ms preprocess, 32.8ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 17it [00:04,  7.18it/s]
# 0: 736x1280 22 players, 1 referee, 32.7ms
# Speed: 10.4ms preprocess, 32.7ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 18it [00:04,  7.15it/s]
# 0: 736x1280 22 players, 2 referees, 32.4ms
# Speed: 11.4ms preprocess, 32.4ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 19it [00:04,  7.08it/s]
# 0: 736x1280 23 players, 2 referees, 33.1ms
# Speed: 10.0ms preprocess, 33.1ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 20it [00:04,  7.21it/s]
# 0: 736x1280 1 ball, 1 goalkeeper, 19 players, 2 referees, 32.4ms
# Speed: 11.2ms preprocess, 32.4ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 21it [00:04,  7.11it/s]
# 0: 736x1280 1 goalkeeper, 21 players, 2 referees, 32.7ms
# Speed: 9.3ms preprocess, 32.7ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 22it [00:05,  7.33it/s]
# 0: 736x1280 1 ball, 1 goalkeeper, 21 players, 2 referees, 32.4ms
# Speed: 6.9ms preprocess, 32.4ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 23it [00:05,  7.29it/s]
# 0: 736x1280 1 goalkeeper, 22 players, 1 referee, 33.1ms
# Speed: 10.3ms preprocess, 33.1ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 24it [00:05,  7.44it/s]
# 0: 736x1280 1 goalkeeper, 22 players, 2 referees, 32.7ms
# Speed: 11.5ms preprocess, 32.7ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 25it [00:05,  4.55it/s]
# embedding extraction: 16it [00:03,  5.09it/s]

# %%
import umap
from sklearn.cluster import KMeans
from sports.common.team import TeamClassifier


REDUCER = umap.UMAP(n_components=3)
CLUSTERING_MODEL = KMeans(n_clusters=2)

projections = REDUCER.fit_transform(data)
clusters = CLUSTERING_MODEL.fit_predict(projections)

frame_generator = sv.get_video_frames_generator(
    source_path=SOURCE_VIDEO_PATH, stride=STRIDE)

crops = []
for frame in tqdm(frame_generator, desc='collecting crops'):
    # result = PLAYER_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
    result = PLAYER_DETECTION_MODEL.predict(frame, conf=0.3)[0]
    # detections = sv.Detections.from_inference(result)
    detections = sv.Detections.from_ultralytics(result)
    players_detections = detections[detections.class_id == PLAYER_ID]
    players_crops = [sv.crop_image(frame, xyxy) for xyxy in detections.xyxy]
    crops += players_crops

team_classifier = TeamClassifier(device="cuda")
team_classifier.fit(crops)
# Out:
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# collecting crops: 0it [00:00, ?it/s]
# 0: 736x1280 1 ball, 2 goalkeepers, 20 players, 2 referees, 33.4ms
# Speed: 13.1ms preprocess, 33.4ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 goalkeeper, 20 players, 2 referees, 32.9ms
# Speed: 9.2ms preprocess, 32.9ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 2it [00:00,  8.43it/s]
# 0: 736x1280 1 goalkeeper, 21 players, 2 referees, 33.1ms
# Speed: 12.2ms preprocess, 33.1ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 3it [00:00,  7.38it/s]
# 0: 736x1280 20 players, 2 referees, 33.1ms
# Speed: 11.3ms preprocess, 33.1ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 4it [00:00,  6.94it/s]
# 0: 736x1280 1 ball, 20 players, 2 referees, 32.7ms
# Speed: 10.1ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 5it [00:00,  6.88it/s]
# 0: 736x1280 1 ball, 20 players, 2 referees, 33.1ms
# Speed: 11.9ms preprocess, 33.1ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 6it [00:00,  6.92it/s]
# 0: 736x1280 20 players, 2 referees, 33.5ms
# Speed: 7.2ms preprocess, 33.5ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 7it [00:00,  6.88it/s]
# 0: 736x1280 1 ball, 19 players, 2 referees, 33.2ms
# Speed: 11.4ms preprocess, 33.2ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 8it [00:01,  6.92it/s]
# 0: 736x1280 1 ball, 1 goalkeeper, 20 players, 2 referees, 32.8ms
# Speed: 10.5ms preprocess, 32.8ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 9it [00:01,  6.86it/s]
# 0: 736x1280 1 ball, 21 players, 2 referees, 32.8ms
# Speed: 11.4ms preprocess, 32.8ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 10it [00:01,  6.71it/s]
# 0: 736x1280 1 ball, 22 players, 2 referees, 33.3ms
# Speed: 11.4ms preprocess, 33.3ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 11it [00:01,  6.64it/s]
# 0: 736x1280 1 ball, 1 goalkeeper, 20 players, 2 referees, 32.7ms
# Speed: 11.3ms preprocess, 32.7ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 12it [00:01,  6.47it/s]
# 0: 736x1280 1 goalkeeper, 21 players, 2 referees, 32.7ms
# Speed: 10.9ms preprocess, 32.7ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 13it [00:01,  6.63it/s]
# 0: 736x1280 1 ball, 1 goalkeeper, 20 players, 2 referees, 33.4ms
# Speed: 7.4ms preprocess, 33.4ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 14it [00:02,  6.61it/s]
# 0: 736x1280 1 goalkeeper, 21 players, 2 referees, 33.0ms
# Speed: 11.5ms preprocess, 33.0ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 15it [00:02,  6.72it/s]
# 0: 736x1280 1 goalkeeper, 21 players, 2 referees, 33.4ms
# Speed: 9.8ms preprocess, 33.4ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 16it [00:02,  6.66it/s]
# 0: 736x1280 20 players, 3 referees, 33.2ms
# Speed: 11.4ms preprocess, 33.2ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 17it [00:02,  6.72it/s]
# 0: 736x1280 22 players, 1 referee, 32.8ms
# Speed: 11.2ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 18it [00:02,  6.72it/s]
# 0: 736x1280 22 players, 2 referees, 33.2ms
# Speed: 10.5ms preprocess, 33.2ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 19it [00:02,  6.69it/s]
# 0: 736x1280 23 players, 2 referees, 33.4ms
# Speed: 10.2ms preprocess, 33.4ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 20it [00:02,  6.87it/s]
# 0: 736x1280 1 ball, 1 goalkeeper, 19 players, 2 referees, 33.3ms
# Speed: 7.0ms preprocess, 33.3ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 21it [00:03,  6.99it/s]
# 0: 736x1280 1 goalkeeper, 21 players, 2 referees, 33.2ms
# Speed: 10.1ms preprocess, 33.2ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 22it [00:03,  7.24it/s]
# 0: 736x1280 1 ball, 1 goalkeeper, 21 players, 2 referees, 33.1ms
# Speed: 7.5ms preprocess, 33.1ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 23it [00:03,  7.22it/s]
# 0: 736x1280 1 goalkeeper, 22 players, 1 referee, 32.7ms
# Speed: 10.4ms preprocess, 32.7ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 24it [00:03,  7.41it/s]
# 0: 736x1280 1 goalkeeper, 22 players, 2 referees, 32.9ms
# Speed: 10.6ms preprocess, 32.9ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
# collecting crops: 25it [00:03,  6.81it/s]
# Embedding extraction: 19it [00:03,  4.84it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.

# %%
import numpy as np
import supervision as sv

def resolve_goalkeepers_team_id(
    players: sv.Detections,
    goalkeepers: sv.Detections
) -> np.ndarray:
    goalkeepers_xy = goalkeepers.get_anchors_coordinates(sv.Position.BOTTOM_CENTER)
    players_xy = players.get_anchors_coordinates(sv.Position.BOTTOM_CENTER)
    team_0_centroid = players_xy[players.class_id == 0].mean(axis=0)
    team_1_centroid = players_xy[players.class_id == 1].mean(axis=0)
    goalkeepers_team_id = []
    for goalkeeper_xy in goalkeepers_xy:
        dist_0 = np.linalg.norm(goalkeeper_xy - team_0_centroid)
        dist_1 = np.linalg.norm(goalkeeper_xy - team_1_centroid)
        goalkeepers_team_id.append(0 if dist_0 < dist_1 else 1)

    return np.array(goalkeepers_team_id)

# %% [markdown]
# ## Tracking Method 1 wih BotSort from Boxmot

# %%
import supervision as sv
from tqdm import tqdm
import numpy as np
from boxmot import BotSort # Import BoTSORT
import cv2
from pathlib import Path
import torch

# ----- Assumed Globals (Make sure these are defined/loaded) -----
# Ensure these models and functions are loaded/defined before use:
# PLAYER_DETECTION_MODEL = ... # Your loaded YOLO model
# team_classifier = ... # Your loaded team classification model
# def resolve_goalkeepers_team_id(players_detections, goalkeepers_detections):
#     # ... implementation ...
#     return goalkeeper_class_ids_array

# ----- Configuration -----
SOURCE_VIDEO_PATH = "app/test_data/raw/0bfacc_0.mp4"
OUTPUT_VIDEO_PATH = "0bfacc_0_botsort_tracked.mp4" # Updated output name
device = torch.device(0) if torch.cuda.is_available() else torch.device('cpu') # Use GPU if available

# Class IDs (as used in your training)
BALL_ID = 0
GOALKEEPER_ID = 1
PLAYER_ID = 2
REFEREE_ID = 3

# ----- Annotators -----
ellipse_annotator = sv.EllipseAnnotator(
    color=sv.ColorPalette.from_hex(['#00BFFF', '#FF1493', '#FFD700']), # Blue, Pink, Yellow for classes 0, 1, 2
    thickness=2
)
label_annotator = sv.LabelAnnotator(
    color=sv.ColorPalette.from_hex(['#00BFFF', '#FF1493', '#FFD700']),
    text_color=sv.Color.from_hex('#000000'),
    text_position=sv.Position.BOTTOM_CENTER
)
triangle_annotator = sv.TriangleAnnotator(
    color=sv.Color.from_hex('#FFD700'), # Assuming you want yellow for the ball
    base=25,
    height=21,
    outline_thickness=1
)

# ----- Tracker Initialization -----
# Initialize BoTSORT tracker
# Common BoTSORT args (adjust as needed based on boxmot documentation/your needs):
# - track_high_thresh: High confidence threshold for starting a track.
# - track_low_thresh: Low confidence threshold for linking.
# - new_track_thresh: Threshold for creating a new track from unmatched detections.
# - track_buffer: Number of frames to keep lost tracks.
# - match_thresh: IoU threshold for matching.
# - proximity_thresh: Proximity threshold (for matching by distance)
# - appearance_thresh: Appearance similarity threshold (if using ReID features)
# - cmc_method: Method for camera motion compensation
# Using default parameters here, specify if needed, e.g., BoTSORT(track_high_thresh=0.5, ...)
tracker = BotSort(
    reid_weights=Path('clip_market1501.pt'),
    device=device,
    half=False,
    with_reid=True,
)
# Note: BoTSORT doesn't typically need an explicit reset like ByteTrack for single video processing.

# ----- Video Processing Setup -----
# Use sv.VideoInfo to get properties like width, height, fps
try:
    video_info = sv.VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
    width, height, fps = video_info.width, video_info.height, video_info.fps
    total_frames = video_info.total_frames or int(fps * 20) # Estimate if total_frames is None, process max 20s
    print(f"Video Info: {width}x{height}, FPS: {fps}, Total Frames: {total_frames}")
except Exception as e:
    print(f"Warning: Could not get video info using supervision. Using defaults. Error: {e}")
    # Fallback if sv.VideoInfo fails or source is not standard video file
    cap = cv2.VideoCapture(SOURCE_VIDEO_PATH)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    cap.release()
    if fps == 0: fps = 30 # Provide a default fps if reading failed
    if total_frames == 0: total_frames = int(fps * 20) # Process max 20 seconds
    print(f"Fallback Video Info: {width}x{height}, FPS: {fps}, Total Frames: {total_frames}")


# Create frame generator
frame_generator = sv.get_video_frames_generator(source_path=SOURCE_VIDEO_PATH, stride=1)

# Initialize video writer
fourcc = cv2.VideoWriter_fourcc(*'mp4v') # or 'avc1', 'XVID'
video_writer = cv2.VideoWriter(OUTPUT_VIDEO_PATH, fourcc, fps, (width, height))

# ----- Frame Processing Function -----
def process_frame(frame: np.ndarray, frame_idx: int):
    """
    Processes a single frame: detects objects, classifies teams, tracks people, annotates.
    """
    # 1. Detection
    # Assuming PLAYER_DETECTION_MODEL outputs results compatible with ultralytics
    result = PLAYER_DETECTION_MODEL.predict(frame, conf=0.3, device=device, verbose=False)[0] # Added verbose=False
    detections = sv.Detections.from_ultralytics(result)

    # 2. Pre-processing Detections
    # Separate ball detections and pad their boxes.
    ball_detections = detections[detections.class_id == BALL_ID]
    if len(ball_detections) > 0:
        ball_detections.xyxy = sv.pad_boxes(xyxy=ball_detections.xyxy, px=10)

    # Get all non-ball detections and apply NMS
    people_detections = detections[detections.class_id != BALL_ID]
    if len(people_detections) > 0:
        people_detections = people_detections.with_nms(threshold=0.5, class_agnostic=True)

    # 3. Team/Role Classification
    players_detections = people_detections[people_detections.class_id == PLAYER_ID]
    goalkeepers_detections = people_detections[people_detections.class_id == GOALKEEPER_ID]
    referees_detections = people_detections[people_detections.class_id == REFEREE_ID]

    # Classify players if any exist
    if len(players_detections) > 0:
        players_crops = [sv.crop_image(frame, xyxy) for xyxy in players_detections.xyxy]
        # Assuming team_classifier.predict returns class IDs (e.g., 0 for team A, 1 for team B)
        players_detections.class_id = team_classifier.predict(players_crops)

    # Classify goalkeepers if any exist
    if len(goalkeepers_detections) > 0:
        # Assuming resolve_goalkeepers_team_id returns class IDs consistent with player teams
        goalkeepers_detections.class_id = resolve_goalkeepers_team_id(players_detections, goalkeepers_detections)

    # Adjust referee class ID (e.g., map to 2 if players/GKs are 0 and 1)
    if len(referees_detections) > 0:
        referees_detections.class_id = np.full(len(referees_detections), 2) # Assign class ID 2 (e.g., Yellow)

    # Merge detections *intended for tracking* (players, goalkeepers, referees)
    detections_to_track = sv.Detections.merge([
        players_detections, goalkeepers_detections, referees_detections
    ])

    # 4. Tracking using BoTSORT
    tracked_detections = sv.Detections.empty() # Initialize as empty
    if len(detections_to_track) > 0:
        # Convert sv.Detections to BoxMOT format: numpy array N x [x1, y1, x2, y2, conf, cls_id]
        boxmot_input = np.hstack((
            detections_to_track.xyxy,
            detections_to_track.confidence[:, np.newaxis], # Ensure confidence is (N, 1)
            detections_to_track.class_id[:, np.newaxis]    # Ensure class_id is (N, 1)
        ))

        # Update BoT-SORT tracker - requires the frame for potential appearance features
        # Output format is typically numpy array N x [x1, y1, x2, y2, track_id, conf, cls, *optional idx*]
        tracks = tracker.update(boxmot_input, frame) # Pass the *original frame*

        # Convert tracker output back to sv.Detections if tracks exist
        if tracks.shape[0] > 0:
            tracked_detections = sv.Detections(
                xyxy=tracks[:, 0:4],
                confidence=tracks[:, 5],
                class_id=tracks[:, 6].astype(int), # Ensure class IDs are integers
                tracker_id=tracks[:, 4].astype(int) # Ensure track IDs are integers
            )
    else:
        # If no detections to track, still update tracker with empty array to advance its state
         tracker.update(np.empty((0, 6)), frame)


    # 5. Annotation
    annotated_frame = frame.copy()

    # Annotate tracked objects (players, GKs, referees)
    if len(tracked_detections) > 0:
        # Create labels with tracker IDs
        labels = [f"#{tid} C{cid}" for tid, cid in zip(tracked_detections.tracker_id, tracked_detections.class_id)]
        # Annotate ellipses based on class ID (0, 1, 2 assigned during classification)
        annotated_frame = ellipse_annotator.annotate(
            scene=annotated_frame,
            detections=tracked_detections # Use class_id from tracked_detections
        )
        # Annotate labels with tracker IDs
        annotated_frame = label_annotator.annotate(
            scene=annotated_frame,
            detections=tracked_detections,
            labels=labels
        )

    # Annotate ball (which is not tracked by BoTSORT in this setup)
    if len(ball_detections) > 0:
        annotated_frame = triangle_annotator.annotate(
            scene=annotated_frame,
            detections=ball_detections
        )

    return annotated_frame

# ----- Main Video Processing Loop -----
with tqdm(total=total_frames, desc="Processing video with BoTSORT") as pbar:
    for frame_idx, frame in enumerate(frame_generator):
        annotated_frame = process_frame(frame, frame_idx)
        video_writer.write(annotated_frame)
        pbar.update(1)
        # Optional: Break early for testing
        # if frame_idx >= fps * 10: # Process only 10 seconds
        #    break

# Release the video writer
video_writer.release()
print(f"Finished processing. Annotated video saved to: {OUTPUT_VIDEO_PATH}")
# Out:
# 2025-04-13 07:02:38.631 | INFO     | boxmot.utils.torch_utils:select_device:52 - Yolo Tracking v12.0.5 🚀 Python-3.11.11 torch-2.5.1+cu121
# CUDA:0 (NVIDIA L4, 22478MiB)
# Resized position embedding: %s to %s torch.Size([197, 768]) torch.Size([129, 768])
# Position embedding resize to height:16 width: 8
# 2025-04-13 07:02:45.022 | SUCCESS  | boxmot.appearance.reid_model_factory:load_pretrained_weights:183 - Loaded pretrained weights from clip_market1501.pt
# Video Info: 1920x1080, FPS: 25, Total Frames: 750
# Embedding extraction: 1it [00:00,  9.28it/s]  | 0/750 [00:00<?, ?it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.44it/s]  | 1/750 [00:03<48:01,  3.85s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.53it/s]  | 2/750 [00:04<22:06,  1.77s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.48it/s]  | 3/750 [00:04<13:48,  1.11s/it]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.43it/s]  | 4/750 [00:04<09:43,  1.28it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.47it/s]  | 5/750 [00:05<07:38,  1.62it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.35it/s]  | 6/750 [00:05<06:18,  1.97it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.45it/s]  | 7/750 [00:05<05:22,  2.31it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.42it/s]  | 8/750 [00:05<04:55,  2.51it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.48it/s]  | 9/750 [00:06<04:37,  2.67it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.61it/s]  | 10/750 [00:06<04:23,  2.80it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.29it/s]  | 11/750 [00:06<04:13,  2.91it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.33it/s]  | 12/750 [00:07<03:54,  3.14it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.60it/s]  | 13/750 [00:07<03:44,  3.28it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.40it/s]  | 14/750 [00:07<03:37,  3.39it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.40it/s]  | 15/750 [00:08<03:33,  3.44it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.35it/s]  | 16/750 [00:08<03:30,  3.49it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.45it/s]  | 17/750 [00:08<03:27,  3.54it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.45it/s]  | 18/750 [00:08<03:27,  3.52it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.48it/s]  | 19/750 [00:09<03:25,  3.56it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.50it/s]  | 20/750 [00:09<03:24,  3.57it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.53it/s]  | 21/750 [00:09<03:23,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.40it/s]  | 22/750 [00:09<03:26,  3.53it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.57it/s]  | 23/750 [00:10<03:24,  3.56it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.43it/s]  | 24/750 [00:10<03:22,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.48it/s]  | 25/750 [00:10<03:22,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.42it/s]  | 26/750 [00:11<03:23,  3.56it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.46it/s]  | 27/750 [00:11<03:22,  3.57it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.53it/s]  | 28/750 [00:11<03:21,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.45it/s]  | 29/750 [00:11<03:21,  3.57it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.50it/s]  | 30/750 [00:12<03:20,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.55it/s]  | 31/750 [00:12<03:19,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.49it/s]  | 32/750 [00:12<03:20,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.48it/s]  | 33/750 [00:13<03:29,  3.42it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.48it/s]  | 34/750 [00:13<03:26,  3.47it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.69it/s]  | 35/750 [00:13<03:25,  3.48it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.33it/s]  | 36/750 [00:13<03:24,  3.49it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]  | 37/750 [00:14<03:24,  3.49it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]  | 38/750 [00:14<03:32,  3.36it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.12it/s]  | 39/750 [00:14<03:32,  3.35it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]  | 40/750 [00:15<03:27,  3.42it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.26it/s]  | 41/750 [00:15<03:27,  3.42it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.77it/s]  | 42/750 [00:15<03:21,  3.51it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.77it/s]  | 43/750 [00:15<03:22,  3.49it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.01it/s]  | 44/750 [00:16<03:32,  3.31it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.55it/s]  | 45/750 [00:16<03:39,  3.21it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.47it/s]  | 46/750 [00:16<03:41,  3.18it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.38it/s]  | 47/750 [00:17<03:40,  3.19it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.40it/s]  | 48/750 [00:17<03:42,  3.16it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.50it/s]  | 49/750 [00:17<03:33,  3.28it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.60it/s]  | 50/750 [00:18<03:30,  3.32it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.48it/s]  | 51/750 [00:18<03:27,  3.37it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.48it/s]  | 52/750 [00:18<03:28,  3.34it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]  | 53/750 [00:19<03:23,  3.43it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.40it/s]  | 54/750 [00:19<03:20,  3.47it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.53it/s]  | 55/750 [00:19<03:18,  3.51it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.42it/s]  | 56/750 [00:19<03:15,  3.55it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.56it/s]  | 57/750 [00:20<03:23,  3.40it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.48it/s]  | 58/750 [00:20<03:19,  3.47it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.35it/s]  | 59/750 [00:20<03:26,  3.34it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.42it/s]  | 60/750 [00:21<03:24,  3.38it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.44it/s]  | 61/750 [00:21<03:21,  3.42it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.36it/s]  | 62/750 [00:21<03:27,  3.32it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.47it/s]  | 63/750 [00:21<03:22,  3.40it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.38it/s]  | 64/750 [00:22<03:26,  3.32it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.52it/s]  | 65/750 [00:22<03:30,  3.26it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]  | 66/750 [00:22<03:33,  3.21it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.22it/s]  | 67/750 [00:23<03:34,  3.18it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.25it/s]  | 68/750 [00:23<03:33,  3.20it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.42it/s]  | 69/750 [00:23<03:35,  3.16it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.45it/s]  | 70/750 [00:24<03:27,  3.28it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.42it/s]  | 71/750 [00:24<03:22,  3.35it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.74it/s]  | 72/750 [00:24<03:25,  3.31it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.44it/s]  | 73/750 [00:25<03:30,  3.21it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.50it/s]  | 74/750 [00:25<03:24,  3.30it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.43it/s]  | 75/750 [00:25<03:28,  3.24it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.42it/s]  | 76/750 [00:25<03:22,  3.34it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.46it/s]  | 77/750 [00:26<03:26,  3.26it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]  | 78/750 [00:26<03:28,  3.22it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.36it/s]  | 79/750 [00:26<03:22,  3.31it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.42it/s]  | 80/750 [00:27<03:17,  3.39it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.43it/s]  | 81/750 [00:27<03:16,  3.40it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]  | 82/750 [00:27<03:14,  3.44it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.35it/s]  | 83/750 [00:28<03:12,  3.46it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]  | 84/750 [00:28<03:19,  3.34it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.38it/s]  | 85/750 [00:28<03:15,  3.40it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.43it/s]  | 86/750 [00:28<03:12,  3.45it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.51it/s]  | 87/750 [00:29<03:19,  3.33it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.34it/s]  | 88/750 [00:29<03:17,  3.35it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.32it/s]  | 89/750 [00:29<03:13,  3.42it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.44it/s]  | 90/750 [00:30<03:12,  3.44it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]  | 91/750 [00:30<03:10,  3.45it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.40it/s]  | 92/750 [00:30<03:17,  3.33it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.49it/s]  | 93/750 [00:31<03:14,  3.37it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.77it/s]  | 94/750 [00:31<03:16,  3.34it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.36it/s]  | 95/750 [00:31<03:16,  3.33it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.29it/s]  | 96/750 [00:31<03:13,  3.39it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.43it/s]  | 97/750 [00:32<03:18,  3.29it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.42it/s]  | 98/750 [00:32<03:22,  3.23it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.43it/s]  | 99/750 [00:32<03:16,  3.31it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.43it/s]  | 100/750 [00:33<03:20,  3.24it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.44it/s]  | 101/750 [00:33<03:22,  3.20it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.44it/s]  | 102/750 [00:33<03:15,  3.31it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.43it/s]  | 103/750 [00:34<03:19,  3.25it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.36it/s]  | 104/750 [00:34<03:13,  3.34it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.36it/s]  | 105/750 [00:34<03:17,  3.26it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.36it/s]  | 106/750 [00:34<03:12,  3.35it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.69it/s]  | 107/750 [00:35<03:09,  3.40it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.71it/s]  | 108/750 [00:35<03:15,  3.28it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.65it/s]  | 109/750 [00:35<03:13,  3.31it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.37it/s]  | 110/750 [00:36<03:10,  3.35it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.39it/s]  | 111/750 [00:36<03:08,  3.39it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.69it/s]  | 112/750 [00:36<03:07,  3.41it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.98it/s]  | 113/750 [00:37<03:07,  3.41it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.45it/s]  | 114/750 [00:37<03:11,  3.32it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.37it/s]  | 115/750 [00:37<03:06,  3.40it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.44it/s]  | 116/750 [00:37<03:12,  3.29it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.38it/s]  | 117/750 [00:38<03:08,  3.36it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.34it/s]  | 118/750 [00:38<03:12,  3.28it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.42it/s]  | 119/750 [00:38<03:07,  3.37it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.43it/s]  | 120/750 [00:39<03:03,  3.44it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.33it/s]  | 121/750 [00:39<03:03,  3.43it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.45it/s]  | 122/750 [00:39<03:00,  3.48it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.38it/s]  | 123/750 [00:40<03:06,  3.36it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.40it/s]  | 124/750 [00:40<03:02,  3.44it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.36it/s]  | 125/750 [00:40<03:07,  3.33it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.35it/s]  | 126/750 [00:40<03:03,  3.40it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.47it/s]  | 127/750 [00:41<03:01,  3.43it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.40it/s]  | 128/750 [00:41<03:07,  3.31it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.29it/s]  | 129/750 [00:41<03:11,  3.24it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]  | 130/750 [00:42<03:14,  3.19it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.36it/s]  | 131/750 [00:42<03:07,  3.31it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.35it/s]  | 132/750 [00:42<03:06,  3.31it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.34it/s]  | 133/750 [00:43<03:02,  3.39it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.34it/s]  | 134/750 [00:43<03:06,  3.30it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.36it/s]  | 135/750 [00:43<03:02,  3.37it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.68it/s]  | 136/750 [00:43<02:59,  3.42it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.35it/s]  | 137/750 [00:44<03:00,  3.40it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.42it/s]  | 138/750 [00:44<03:05,  3.30it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.38it/s]  | 139/750 [00:44<03:00,  3.39it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.33it/s]  | 140/750 [00:45<02:58,  3.41it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.35it/s]  | 141/750 [00:45<03:04,  3.30it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.07it/s]  | 142/750 [00:45<03:00,  3.37it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.69it/s]  | 143/750 [00:45<02:58,  3.40it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.64it/s]  | 144/750 [00:46<02:59,  3.38it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.34it/s]  | 145/750 [00:46<03:05,  3.25it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.39it/s]  | 146/750 [00:46<03:01,  3.33it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.36it/s]  | 147/750 [00:47<03:04,  3.26it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.69it/s]  | 148/750 [00:47<03:03,  3.29it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.67it/s]  | 149/750 [00:47<02:59,  3.35it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.70it/s]  | 150/750 [00:48<02:57,  3.39it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.72it/s]  | 151/750 [00:48<02:57,  3.37it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.04it/s]  | 152/750 [00:48<03:05,  3.22it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.29it/s]  | 153/750 [00:49<03:03,  3.26it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.29it/s]  | 154/750 [00:49<03:03,  3.25it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.71it/s]  | 155/750 [00:49<03:10,  3.13it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.76it/s]  | 156/750 [00:49<03:03,  3.23it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.66it/s]  | 157/750 [00:50<03:07,  3.16it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.72it/s]  | 158/750 [00:50<03:03,  3.22it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.71it/s]  | 159/750 [00:50<03:09,  3.11it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.73it/s]  | 160/750 [00:51<03:12,  3.06it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.70it/s]  | 161/750 [00:51<03:06,  3.16it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.71it/s]  | 162/750 [00:51<03:09,  3.11it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.67it/s]  | 163/750 [00:52<03:05,  3.17it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.72it/s]  | 164/750 [00:52<03:03,  3.19it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.68it/s]  | 165/750 [00:52<03:01,  3.23it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.67it/s]  | 166/750 [00:53<02:58,  3.26it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.67it/s]  | 167/750 [00:53<02:58,  3.27it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.70it/s]  | 168/750 [00:53<02:56,  3.30it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.69it/s]  | 169/750 [00:54<02:54,  3.32it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.64it/s]  | 170/750 [00:54<03:01,  3.19it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.71it/s]  | 171/750 [00:54<02:58,  3.24it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.67it/s]  | 172/750 [00:54<02:56,  3.28it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.69it/s]  | 173/750 [00:55<02:54,  3.30it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.69it/s]  | 174/750 [00:55<02:52,  3.35it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.62it/s]  | 175/750 [00:55<02:51,  3.36it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.67it/s]  | 176/750 [00:56<02:56,  3.25it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.67it/s]  | 177/750 [00:56<02:53,  3.31it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.66it/s]  | 178/750 [00:56<02:58,  3.21it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.59it/s]  | 179/750 [00:57<02:54,  3.28it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.72it/s]  | 180/750 [00:57<02:52,  3.31it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.66it/s]  | 181/750 [00:57<02:51,  3.32it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.63it/s]  | 182/750 [00:57<02:50,  3.33it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.69it/s]  | 183/750 [00:58<02:49,  3.34it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.65it/s]  | 184/750 [00:58<02:48,  3.35it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.66it/s]  | 185/750 [00:58<02:48,  3.34it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.71it/s]  | 186/750 [00:59<02:47,  3.36it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.69it/s]  | 187/750 [00:59<02:47,  3.37it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.66it/s]  | 188/750 [00:59<02:47,  3.36it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.66it/s]  | 189/750 [01:00<02:46,  3.36it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.65it/s]  | 190/750 [01:00<02:54,  3.22it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.60it/s]  | 191/750 [01:00<02:58,  3.13it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.33it/s]  | 192/750 [01:01<02:54,  3.20it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.58it/s]  | 193/750 [01:01<02:48,  3.30it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.66it/s]  | 194/750 [01:01<02:48,  3.29it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.65it/s]  | 195/750 [01:01<02:47,  3.31it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.67it/s]  | 196/750 [01:02<02:53,  3.19it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.25it/s]  | 197/750 [01:02<02:50,  3.24it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.50it/s]  | 198/750 [01:02<02:50,  3.23it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.33it/s]  | 199/750 [01:03<02:53,  3.17it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.52it/s]  | 200/750 [01:03<02:59,  3.07it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.33it/s]  | 201/750 [01:03<02:50,  3.22it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.28it/s]  | 202/750 [01:04<02:45,  3.30it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.27it/s]  | 203/750 [01:04<02:43,  3.35it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.33it/s]  | 204/750 [01:04<02:40,  3.40it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.33it/s]  | 205/750 [01:04<02:41,  3.37it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.39it/s]  | 206/750 [01:05<02:46,  3.28it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]  | 207/750 [01:05<02:41,  3.35it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.19it/s]  | 208/750 [01:05<02:39,  3.40it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.36it/s]  | 209/750 [01:06<02:37,  3.44it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.30it/s]  | 210/750 [01:06<02:35,  3.47it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.33it/s]  | 211/750 [01:06<02:41,  3.34it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.35it/s]  | 212/750 [01:07<02:37,  3.42it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.33it/s]  | 213/750 [01:07<02:35,  3.46it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.28it/s]  | 214/750 [01:07<02:33,  3.49it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.39it/s]  | 215/750 [01:07<02:39,  3.36it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.31it/s]  | 216/750 [01:08<02:36,  3.41it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.32it/s]  | 217/750 [01:08<02:34,  3.45it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.34it/s]  | 218/750 [01:08<02:33,  3.48it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.34it/s]  | 219/750 [01:09<02:31,  3.50it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.32it/s]  | 220/750 [01:09<02:37,  3.36it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.34it/s]  | 221/750 [01:09<02:34,  3.41it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.33it/s]  | 222/750 [01:09<02:32,  3.46it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.36it/s]  | 223/750 [01:10<02:31,  3.49it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.42it/s]  | 224/750 [01:10<02:29,  3.52it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.26it/s]  | 225/750 [01:10<02:29,  3.52it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.35it/s]  | 226/750 [01:11<02:28,  3.52it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.35it/s]  | 227/750 [01:11<02:28,  3.53it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.31it/s]  | 228/750 [01:11<02:28,  3.51it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.33it/s]  | 229/750 [01:11<02:27,  3.53it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.37it/s]  | 230/750 [01:12<02:26,  3.54it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.60it/s]  | 231/750 [01:12<02:25,  3.57it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.39it/s]  | 232/750 [01:12<02:26,  3.53it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]  | 233/750 [01:13<02:26,  3.54it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.44it/s]  | 234/750 [01:13<02:25,  3.55it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.37it/s]  | 235/750 [01:13<02:24,  3.57it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.37it/s]  | 236/750 [01:13<02:24,  3.57it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]  | 237/750 [01:14<02:23,  3.57it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.72it/s]  | 238/750 [01:14<02:23,  3.57it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.65it/s]  | 239/750 [01:14<02:25,  3.51it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.71it/s]  | 240/750 [01:15<02:27,  3.45it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.66it/s]  | 241/750 [01:15<02:30,  3.39it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.70it/s]  | 242/750 [01:15<02:31,  3.36it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.02it/s]  | 243/750 [01:15<02:31,  3.34it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.29it/s]  | 244/750 [01:16<02:29,  3.39it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.65it/s]  | 245/750 [01:16<02:27,  3.42it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.62it/s]  | 246/750 [01:16<02:27,  3.41it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.67it/s]  | 247/750 [01:17<02:34,  3.25it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.70it/s]  | 248/750 [01:17<02:33,  3.28it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.72it/s]  | 249/750 [01:17<02:31,  3.31it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.43it/s]  | 250/750 [01:18<02:32,  3.28it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.61it/s]  | 251/750 [01:18<02:32,  3.26it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.66it/s]  | 252/750 [01:18<02:32,  3.26it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.66it/s]  | 253/750 [01:18<02:30,  3.30it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.65it/s]  | 254/750 [01:19<02:29,  3.32it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.30it/s]  | 255/750 [01:19<02:28,  3.33it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.35it/s]  | 256/750 [01:19<02:25,  3.38it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# ...
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.19it/s]▊ | 665/750 [03:21<00:25,  3.32it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.26it/s]▉ | 666/750 [03:22<00:25,  3.33it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.26it/s]▉ | 667/750 [03:22<00:25,  3.24it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.39it/s]▉ | 668/750 [03:22<00:26,  3.12it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.26it/s]▉ | 669/750 [03:23<00:24,  3.24it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.29it/s]▉ | 670/750 [03:23<00:24,  3.28it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.32it/s]▉ | 671/750 [03:23<00:24,  3.22it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.31it/s]▉ | 672/750 [03:24<00:23,  3.30it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.37it/s]▉ | 673/750 [03:24<00:23,  3.23it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.36it/s]▉ | 674/750 [03:24<00:23,  3.30it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.25it/s]█ | 675/750 [03:25<00:22,  3.36it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.30it/s]█ | 676/750 [03:25<00:21,  3.38it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.33it/s]█ | 677/750 [03:25<00:21,  3.43it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.45it/s]█ | 678/750 [03:25<00:20,  3.48it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.40it/s]█ | 679/750 [03:26<00:20,  3.52it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.40it/s]█ | 680/750 [03:26<00:19,  3.52it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.11it/s]█ | 681/750 [03:26<00:19,  3.54it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.27it/s]█ | 682/750 [03:27<00:20,  3.39it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.18it/s]█ | 683/750 [03:27<00:19,  3.43it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.18it/s]█ | 684/750 [03:27<00:19,  3.47it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.33it/s]█▏| 685/750 [03:27<00:19,  3.42it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.04it/s]█▏| 686/750 [03:28<00:18,  3.48it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.33it/s]█▏| 687/750 [03:28<00:18,  3.37it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.17it/s]█▏| 688/750 [03:28<00:18,  3.29it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.07it/s]█▏| 689/750 [03:29<00:18,  3.29it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.07it/s]█▏| 690/750 [03:29<00:18,  3.29it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.11it/s]█▏| 691/750 [03:29<00:17,  3.28it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.87it/s]█▏| 692/750 [03:29<00:16,  3.42it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.10it/s]█▏| 693/750 [03:30<00:16,  3.38it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.16it/s]█▎| 694/750 [03:30<00:16,  3.45it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.27it/s]█▎| 695/750 [03:30<00:15,  3.47it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.21it/s]█▎| 696/750 [03:31<00:15,  3.50it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.06it/s]█▎| 697/750 [03:31<00:15,  3.50it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.28it/s]█▎| 698/750 [03:31<00:14,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.24it/s]█▎| 699/750 [03:31<00:14,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.27it/s]█▎| 700/750 [03:32<00:13,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.35it/s]█▎| 701/750 [03:32<00:13,  3.55it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.38it/s]█▎| 702/750 [03:32<00:13,  3.55it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.29it/s]█▎| 703/750 [03:33<00:13,  3.55it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.29it/s]█▍| 704/750 [03:33<00:12,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.36it/s]█▍| 705/750 [03:33<00:12,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.35it/s]█▍| 706/750 [03:33<00:12,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.26it/s]█▍| 707/750 [03:34<00:11,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.31it/s]█▍| 708/750 [03:34<00:11,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.37it/s]█▍| 709/750 [03:34<00:11,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.34it/s]█▍| 710/750 [03:35<00:11,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.34it/s]█▍| 711/750 [03:35<00:11,  3.50it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.35it/s]█▍| 712/750 [03:35<00:11,  3.38it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.40it/s]█▌| 713/750 [03:35<00:10,  3.43it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.34it/s]█▌| 714/750 [03:36<00:10,  3.49it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.16it/s]█▌| 715/750 [03:36<00:10,  3.44it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.11it/s]█▌| 716/750 [03:36<00:09,  3.49it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.30it/s]█▌| 717/750 [03:37<00:09,  3.46it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.78it/s]█▌| 718/750 [03:37<00:09,  3.34it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.67it/s]█▌| 719/750 [03:37<00:09,  3.37it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.09it/s]█▌| 720/750 [03:37<00:08,  3.53it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.55it/s]█▌| 721/750 [03:38<00:08,  3.45it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.47it/s]█▋| 722/750 [03:38<00:07,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.63it/s]█▋| 723/750 [03:38<00:07,  3.66it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.64it/s]█▋| 724/750 [03:39<00:07,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.96it/s]█▋| 725/750 [03:39<00:07,  3.53it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.48it/s]█▋| 726/750 [03:39<00:06,  3.53it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.99it/s]█▋| 727/750 [03:39<00:06,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.37it/s]█▋| 728/750 [03:40<00:06,  3.49it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.06it/s]█▋| 729/750 [03:40<00:06,  3.38it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.48it/s]█▋| 730/750 [03:40<00:05,  3.50it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.36it/s]█▋| 731/750 [03:41<00:05,  3.51it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.27it/s]█▊| 732/750 [03:41<00:05,  3.54it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.03it/s]█▊| 733/750 [03:41<00:04,  3.54it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.33it/s]█▊| 734/750 [03:41<00:04,  3.53it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.37it/s]█▊| 735/750 [03:42<00:04,  3.49it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.17it/s]█▊| 736/750 [03:42<00:04,  3.38it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.37it/s]█▊| 737/750 [03:42<00:03,  3.29it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.00it/s]█▊| 738/750 [03:43<00:03,  3.25it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.27it/s]█▊| 739/750 [03:43<00:03,  3.37it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.19it/s]█▊| 740/750 [03:43<00:02,  3.44it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.38it/s]█▉| 741/750 [03:43<00:02,  3.46it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.33it/s]█▉| 742/750 [03:44<00:02,  3.35it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.29it/s]█▉| 743/750 [03:44<00:02,  3.36it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.06it/s]█▉| 744/750 [03:44<00:01,  3.29it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.11it/s]█▉| 745/750 [03:45<00:01,  3.29it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.34it/s]█▉| 746/750 [03:45<00:01,  3.45it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.24it/s]█▉| 747/750 [03:45<00:00,  3.49it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.22it/s]█▉| 748/750 [03:46<00:00,  3.51it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.23it/s]█▉| 749/750 [03:46<00:00,  3.38it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Processing video with BoTSORT: 100%|██████████| 750/750 [03:46<00:00,  3.31it/s]
# Finished processing. Annotated video saved to: 0bfacc_0_botsort_tracked.mp4

# %% [markdown]
# ## Tracking Method 2 wih BotSort from Ultralytics

# %%
import supervision as sv
from tqdm import tqdm
import numpy as np
# from boxmot import BoTSORT # No longer needed directly
import cv2
from pathlib import Path
import torch
from ultralytics import YOLO # Import YOLO from ultralytics

# ----- Assumed Globals (Make sure these are defined/loaded) -----
# Ensure these models and functions are loaded/defined before use:
# team_classifier = ... # Your loaded team classification model
# def resolve_goalkeepers_team_id(players_detections, goalkeepers_detections):
#     # ... implementation returning numpy array of class IDs ...
#     return goalkeeper_class_ids_array

# ----- Configuration -----
SOURCE_VIDEO_PATH = "app/test_data/raw/0bfacc_0.mp4"
OUTPUT_VIDEO_PATH = "0bfacc_0_ultralytics_botsort_tracked_2.mp4" # Updated output name
YOLO_MODEL_PATH = "app/models/yolo11_football_v2/weights/best.pt" # Or your custom trained YOLO model path
TRACKER_CONFIG = "botsort.yaml" # Make sure this config file is available or use default

device = torch.device(0) if torch.cuda.is_available() else torch.device('cpu')

# --- IMPORTANT: Define Class IDs as used by your YOLO model ---
# These MUST match the class IDs your YOLO model was trained with
BALL_ID = 0         # Example: Ball is class 0 in the YOLO model
GOALKEEPER_ID = 1   # Example: Goalkeeper is class 1
PLAYER_ID = 2       # Example: Player is class 2
REFEREE_ID = 3      # Example: Referee is class 3

# --- Define NEW Class IDs for Annotation (after team classification) ---
# These will be used by the annotators AFTER your custom logic.
# Let's say Team A = 0, Team B = 1, Referee = 2
TEAM_A_ID = 0
TEAM_B_ID = 1
ANNOTATION_REFEREE_ID = 2
# We'll map the classified players/GKs to TEAM_A_ID or TEAM_B_ID
# We'll map detected referees to ANNOTATION_REFEREE_ID

# ----- Load YOLO Model -----
model = YOLO(YOLO_MODEL_PATH)
model.to(device)

# ----- Annotators -----
# Use colors corresponding to the NEW annotation IDs (Team A, Team B, Referee)
ellipse_annotator = sv.EllipseAnnotator(
    color=sv.ColorPalette.from_hex(['#00BFFF', '#FF1493', '#FFD700']), # Team A (Blue), Team B (Pink), Referee (Yellow)
    thickness=2
)
label_annotator = sv.LabelAnnotator(
    color=sv.ColorPalette.from_hex(['#00BFFF', '#FF1493', '#FFD700']),
    text_color=sv.Color.from_hex('#000000'),
    text_position=sv.Position.BOTTOM_CENTER,
    text_scale=0.6 # Smaller text
)
triangle_annotator = sv.TriangleAnnotator(
    color=sv.Color.from_hex('#32CD32'), # Lime green for ball
    base=25,
    height=21,
    outline_thickness=1
)

# ----- Video Processing Setup -----
try:
    video_info = sv.VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
    width, height, fps = video_info.width, video_info.height, video_info.fps
    total_frames = video_info.total_frames or int(fps * 20) # Estimate if total_frames is None
    print(f"Video Info: {width}x{height}, FPS: {fps}, Total Frames: {total_frames}")
except Exception as e:
    print(f"Warning: Could not get video info using supervision. Using defaults. Error: {e}")
    # Fallback if sv.VideoInfo fails
    cap = cv2.VideoCapture(SOURCE_VIDEO_PATH)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    cap.release()
    if fps == 0: fps = 30
    if total_frames == 0: total_frames = int(fps * 20)
    print(f"Fallback Video Info: {width}x{height}, FPS: {fps}, Total Frames: {total_frames}")

frame_generator = sv.get_video_frames_generator(source_path=SOURCE_VIDEO_PATH, stride=1)

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
video_writer = cv2.VideoWriter(OUTPUT_VIDEO_PATH, fourcc, fps, (width, height))

# ----- Main Video Processing Loop -----
with tqdm(total=total_frames, desc=f"Tracking with BoT-SORT ({TRACKER_CONFIG})") as pbar:
    for frame_idx, frame in enumerate(frame_generator):
        # 1. Run Integrated Detection and Tracking (Only for player-like objects)
        # We track only the classes we intend to classify later.
        # 'persist=True' maintains tracker state across frames.
        # 'classes' filters detections BEFORE tracking.
        results = model.track(
            source=frame,
            persist=True,
            tracker=TRACKER_CONFIG,
            classes=[GOALKEEPER_ID, PLAYER_ID, REFEREE_ID], # Track only these initial IDs
            conf=0.3, # Confidence threshold for initial detection
            verbose=False, # Suppress Ultralytics console output per frame
            device=device
        )

        # Separately detect the ball (as it's not classified/tracked the same way)
        # Using predict for ball allows different confidence etc.
        ball_results = model.predict(frame, classes=[BALL_ID], conf=0.1, verbose=False, device=device)
        ball_detections = sv.Detections.from_ultralytics(ball_results[0])
        if len(ball_detections) > 0:
             ball_detections.xyxy = sv.pad_boxes(xyxy=ball_detections.xyxy, px=10)


        # 2. Process Tracking Results
        annotated_frame = frame.copy()
        detections_for_annotation = sv.Detections.empty() # Start with empty detections

        if results[0].boxes.id is not None: # Check if tracking IDs are assigned
            # Convert tracked results to Supervision Detections object
            # This object contains xyxy, confidence, original class_id, and tracker_id
            tracked_detections = sv.Detections.from_ultralytics(results[0])

            # 3. Apply Custom Classification based on TRACKED items
            # Filter detections based on ORIGINAL class ID from YOLO
            players = tracked_detections[tracked_detections.class_id == PLAYER_ID]
            goalkeepers = tracked_detections[tracked_detections.class_id == GOALKEEPER_ID]
            referees = tracked_detections[tracked_detections.class_id == REFEREE_ID]

            final_detections_list = []

            # Process Players
            if len(players) > 0:
                player_crops = [sv.crop_image(frame, xyxy) for xyxy in players.xyxy]
                # Assume team_classifier returns an array of TEAM_A_ID or TEAM_B_ID
                new_player_class_ids = team_classifier.predict(player_crops)
                players.class_id = new_player_class_ids # OVERWRITE class ID for annotation
                final_detections_list.append(players)

            # Process Goalkeepers
            if len(goalkeepers) > 0:
                # Assume resolve_goalkeepers_team_id uses players info and returns TEAM_A_ID/TEAM_B_ID
                new_gk_class_ids = resolve_goalkeepers_team_id(players, goalkeepers) # Pass sv.Detections
                goalkeepers.class_id = new_gk_class_ids # OVERWRITE class ID for annotation
                final_detections_list.append(goalkeepers)

            # Process Referees
            if len(referees) > 0:
                # Assign the predefined annotation ID for referees
                referees.class_id = np.full(len(referees), ANNOTATION_REFEREE_ID)
                final_detections_list.append(referees)

            # Merge all processed detections back together for annotation
            if final_detections_list:
                 detections_for_annotation = sv.Detections.merge(final_detections_list)


        # 4. Annotation using Supervision
        # Annotate tracked+classified objects
        if len(detections_for_annotation) > 0:
            # Create labels using tracker ID and the NEW class ID
            labels = [
                f"T:{tid} C:{cid}"
                for tid, cid
                in zip(detections_for_annotation.tracker_id, detections_for_annotation.class_id)
            ]
            # Annotate ellipses based on the NEW class ID (Team A, Team B, Referee)
            annotated_frame = ellipse_annotator.annotate(
                scene=annotated_frame,
                detections=detections_for_annotation
            )
            # Annotate labels
            annotated_frame = label_annotator.annotate(
                scene=annotated_frame,
                detections=detections_for_annotation,
                labels=labels
            )

        # Annotate the ball separately
        if len(ball_detections) > 0:
            annotated_frame = triangle_annotator.annotate(
                scene=annotated_frame,
                detections=ball_detections
            )

        # 5. Write Frame
        video_writer.write(annotated_frame)
        pbar.update(1)

# Release resources
video_writer.release()
print(f"Finished processing. Annotated video saved to: {OUTPUT_VIDEO_PATH}")
# Optional: Close any CV2 windows if you were displaying frames live
# cv2.destroyAllWindows()
# Out:
# Video Info: 1920x1080, FPS: 25, Total Frames: 750
# Embedding extraction: 1it [00:00,  8.45it/s]          | 0/750 [00:00<?, ?it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.43it/s]          | 1/750 [00:00<09:32,  1.31it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.53it/s]          | 2/750 [00:01<05:51,  2.13it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.49it/s]          | 3/750 [00:01<04:41,  2.66it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.52it/s]          | 4/750 [00:01<04:05,  3.03it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.49it/s]          | 5/750 [00:01<03:46,  3.29it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.48it/s]          | 6/750 [00:02<03:39,  3.40it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.31it/s]          | 7/750 [00:02<03:30,  3.53it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]          | 8/750 [00:02<03:22,  3.67it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.64it/s]          | 9/750 [00:02<03:19,  3.71it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.64it/s]▏         | 10/750 [00:03<03:17,  3.75it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.40it/s]▏         | 11/750 [00:03<03:14,  3.79it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.29it/s]▏         | 12/750 [00:03<03:10,  3.87it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.53it/s]▏         | 13/750 [00:03<03:08,  3.90it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.47it/s]▏         | 14/750 [00:04<03:08,  3.91it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.55it/s]▏         | 15/750 [00:04<03:08,  3.91it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.55it/s]▏         | 16/750 [00:04<03:11,  3.82it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.51it/s]▏         | 17/750 [00:04<03:14,  3.77it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.43it/s]▏         | 18/750 [00:05<03:15,  3.74it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.52it/s]▎         | 19/750 [00:05<03:13,  3.78it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.57it/s]▎         | 20/750 [00:05<03:15,  3.74it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.48it/s]▎         | 21/750 [00:06<03:15,  3.72it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.54it/s]▎         | 22/750 [00:06<03:16,  3.71it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.55it/s]▎         | 23/750 [00:06<03:16,  3.69it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.52it/s]▎         | 24/750 [00:06<03:16,  3.70it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.55it/s]▎         | 25/750 [00:07<03:16,  3.69it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.47it/s]▎         | 26/750 [00:07<03:16,  3.68it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.46it/s]▎         | 27/750 [00:07<03:16,  3.67it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.39it/s]▎         | 28/750 [00:07<03:17,  3.65it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.46it/s]▍         | 29/750 [00:08<03:15,  3.68it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.48it/s]▍         | 30/750 [00:08<03:16,  3.66it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.49it/s]▍         | 31/750 [00:08<03:16,  3.66it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.52it/s]▍         | 32/750 [00:09<03:17,  3.64it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.58it/s]▍         | 33/750 [00:09<03:16,  3.64it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.51it/s]▍         | 34/750 [00:09<03:16,  3.64it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.48it/s]▍         | 35/750 [00:09<03:16,  3.64it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.46it/s]▍         | 36/750 [00:10<03:16,  3.63it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.44it/s]▍         | 37/750 [00:10<03:16,  3.63it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.47it/s]▌         | 38/750 [00:10<03:16,  3.63it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.40it/s]▌         | 39/750 [00:10<03:15,  3.64it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.76it/s]▌         | 40/750 [00:11<03:11,  3.70it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.79it/s]▌         | 41/750 [00:11<03:12,  3.69it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.81it/s]▌         | 42/750 [00:11<03:11,  3.70it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.79it/s]▌         | 43/750 [00:12<03:11,  3.69it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.75it/s]▌         | 44/750 [00:12<03:14,  3.63it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.82it/s]▌         | 45/750 [00:12<03:17,  3.57it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.49it/s]▌         | 46/750 [00:12<03:19,  3.52it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.49it/s]▋         | 47/750 [00:13<03:18,  3.55it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.52it/s]▋         | 48/750 [00:13<03:16,  3.57it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]▋         | 49/750 [00:13<03:15,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.58it/s]▋         | 50/750 [00:13<03:15,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.60it/s]▋         | 51/750 [00:14<03:11,  3.65it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]▋         | 52/750 [00:14<03:08,  3.71it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.52it/s]▋         | 53/750 [00:14<03:05,  3.75it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.55it/s]▋         | 54/750 [00:15<03:03,  3.79it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.55it/s]▋         | 55/750 [00:15<03:06,  3.73it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.45it/s]▋         | 56/750 [00:15<03:07,  3.71it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.54it/s]▊         | 57/750 [00:15<03:08,  3.68it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.46it/s]▊         | 58/750 [00:16<03:05,  3.73it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]▊         | 59/750 [00:16<03:03,  3.77it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.47it/s]▊         | 60/750 [00:16<03:05,  3.72it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.08it/s]▊         | 61/750 [00:16<03:07,  3.67it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.47it/s]▊         | 62/750 [00:17<03:11,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.53it/s]▊         | 63/750 [00:17<03:10,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.44it/s]▊         | 64/750 [00:17<03:10,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.48it/s]▊         | 65/750 [00:18<03:10,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.51it/s]▉         | 66/750 [00:18<03:09,  3.61it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.64it/s]▉         | 67/750 [00:18<03:09,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.60it/s]▉         | 68/750 [00:18<03:09,  3.61it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.58it/s]▉         | 69/750 [00:19<03:08,  3.61it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.54it/s]▉         | 70/750 [00:19<03:08,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.68it/s]▉         | 71/750 [00:19<03:08,  3.61it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.90it/s]▉         | 72/750 [00:20<03:08,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.69it/s]▉         | 73/750 [00:20<03:09,  3.57it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.68it/s]▉         | 74/750 [00:20<03:09,  3.57it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.51it/s]█         | 75/750 [00:20<03:08,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.44it/s]█         | 76/750 [00:21<03:08,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.47it/s]█         | 77/750 [00:21<03:07,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.40it/s]█         | 78/750 [00:21<03:06,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.48it/s]█         | 79/750 [00:21<03:06,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]█         | 80/750 [00:22<03:05,  3.61it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.46it/s]█         | 81/750 [00:22<03:06,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.51it/s]█         | 82/750 [00:22<03:05,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.59it/s]█         | 83/750 [00:23<03:05,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.39it/s]█         | 84/750 [00:23<03:04,  3.62it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.48it/s]█▏        | 85/750 [00:23<03:03,  3.62it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.44it/s]█▏        | 86/750 [00:23<03:03,  3.62it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.48it/s]█▏        | 87/750 [00:24<03:03,  3.62it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.44it/s]█▏        | 88/750 [00:24<03:03,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.44it/s]█▏        | 89/750 [00:24<03:03,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.50it/s]█▏        | 90/750 [00:25<03:04,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.52it/s]█▏        | 91/750 [00:25<03:03,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.15it/s]█▏        | 92/750 [00:25<03:02,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.40it/s]█▏        | 93/750 [00:25<02:56,  3.72it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.74it/s]█▎        | 94/750 [00:26<02:54,  3.75it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.03it/s]█▎        | 95/750 [00:26<02:55,  3.73it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.64it/s]█▎        | 96/750 [00:26<02:54,  3.74it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.34it/s]█▎        | 97/750 [00:26<02:52,  3.78it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.44it/s]█▎        | 98/750 [00:27<02:53,  3.77it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.38it/s]█▎        | 99/750 [00:27<02:52,  3.78it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.38it/s]█▎        | 100/750 [00:27<02:54,  3.72it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.43it/s]█▎        | 101/750 [00:27<02:56,  3.68it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.46it/s]█▎        | 102/750 [00:28<02:56,  3.66it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.44it/s]█▎        | 103/750 [00:28<02:57,  3.64it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.45it/s]█▍        | 104/750 [00:28<02:58,  3.62it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.39it/s]█▍        | 105/750 [00:29<02:58,  3.61it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.53it/s]█▍        | 106/750 [00:29<02:58,  3.61it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.79it/s]█▍        | 107/750 [00:29<02:58,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.74it/s]█▍        | 108/750 [00:29<03:00,  3.56it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.76it/s]█▍        | 109/750 [00:30<03:01,  3.53it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.34it/s]█▍        | 110/750 [00:30<03:02,  3.50it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.43it/s]█▍        | 111/750 [00:30<03:01,  3.52it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.73it/s]█▍        | 112/750 [00:31<03:00,  3.54it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.90it/s]█▌        | 113/750 [00:31<03:01,  3.52it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.51it/s]█▌        | 114/750 [00:31<03:01,  3.50it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.47it/s]█▌        | 115/750 [00:31<02:59,  3.53it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.50it/s]█▌        | 116/750 [00:32<02:58,  3.55it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.60it/s]█▌        | 117/750 [00:32<02:57,  3.56it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.43it/s]█▌        | 118/750 [00:32<02:56,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]█▌        | 119/750 [00:33<02:54,  3.61it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.31it/s]█▌        | 120/750 [00:33<02:54,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.51it/s]█▌        | 121/750 [00:33<02:54,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.40it/s]█▋        | 122/750 [00:33<02:53,  3.61it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.45it/s]█▋        | 123/750 [00:34<02:53,  3.62it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.37it/s]█▋        | 124/750 [00:34<02:53,  3.61it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.42it/s]█▋        | 125/750 [00:34<02:53,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.47it/s]█▋        | 126/750 [00:34<02:53,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.36it/s]█▋        | 127/750 [00:35<02:52,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.32it/s]█▋        | 128/750 [00:35<02:49,  3.67it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.43it/s]█▋        | 129/750 [00:35<02:47,  3.71it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.43it/s]█▋        | 130/750 [00:36<02:46,  3.73it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.44it/s]█▋        | 131/750 [00:36<02:47,  3.69it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]█▊        | 132/750 [00:36<02:48,  3.67it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.38it/s]█▊        | 133/750 [00:36<02:49,  3.65it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]█▊        | 134/750 [00:37<02:46,  3.70it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.44it/s]█▊        | 135/750 [00:37<02:47,  3.66it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.45it/s]█▊        | 136/750 [00:37<02:50,  3.61it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.46it/s]█▊        | 137/750 [00:37<02:49,  3.61it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]█▊        | 138/750 [00:38<02:50,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.40it/s]█▊        | 139/750 [00:38<02:50,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.37it/s]█▊        | 140/750 [00:38<02:49,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.42it/s]█▉        | 141/750 [00:39<02:50,  3.57it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.43it/s]█▉        | 142/750 [00:39<02:50,  3.57it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.36it/s]█▉        | 143/750 [00:39<02:49,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.37it/s]█▉        | 144/750 [00:39<02:49,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.44it/s]█▉        | 145/750 [00:40<02:49,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.38it/s]█▉        | 146/750 [00:40<02:45,  3.64it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.35it/s]█▉        | 147/750 [00:40<02:42,  3.70it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.70it/s]█▉        | 148/750 [00:40<02:41,  3.73it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.31it/s]█▉        | 149/750 [00:41<02:41,  3.73it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.33it/s]██        | 150/750 [00:41<02:45,  3.62it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.30it/s]██        | 151/750 [00:41<02:45,  3.61it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.33it/s]██        | 152/750 [00:42<02:45,  3.61it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.23it/s]██        | 153/750 [00:42<02:46,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.33it/s]██        | 154/750 [00:42<02:46,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.32it/s]██        | 155/750 [00:42<02:45,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.28it/s]██        | 156/750 [00:43<02:45,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.73it/s]██        | 157/750 [00:43<02:45,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.70it/s]██        | 158/750 [00:43<02:43,  3.61it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.70it/s]██        | 159/750 [00:44<02:45,  3.57it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.70it/s]██▏       | 160/750 [00:44<02:47,  3.52it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.68it/s]██▏       | 161/750 [00:44<02:48,  3.49it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.76it/s]██▏       | 162/750 [00:44<02:49,  3.47it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.69it/s]██▏       | 163/750 [00:45<02:49,  3.47it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.74it/s]██▏       | 164/750 [00:45<02:48,  3.47it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.72it/s]██▏       | 165/750 [00:45<02:48,  3.47it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.65it/s]██▏       | 166/750 [00:46<02:48,  3.46it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.73it/s]██▏       | 167/750 [00:46<02:45,  3.53it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.49it/s]██▏       | 168/750 [00:46<02:45,  3.52it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.83it/s]██▎       | 169/750 [00:46<02:46,  3.49it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.74it/s]██▎       | 170/750 [00:47<02:46,  3.48it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.70it/s]██▎       | 171/750 [00:47<02:46,  3.48it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.71it/s]██▎       | 172/750 [00:47<02:46,  3.47it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.74it/s]██▎       | 173/750 [00:48<02:43,  3.53it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.65it/s]██▎       | 174/750 [00:48<02:45,  3.48it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.73it/s]██▎       | 175/750 [00:48<02:45,  3.48it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.89it/s]██▎       | 176/750 [00:48<02:44,  3.49it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.64it/s]██▎       | 177/750 [00:49<02:43,  3.51it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.70it/s]██▎       | 178/750 [00:49<02:40,  3.57it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.67it/s]██▍       | 179/750 [00:49<02:38,  3.61it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.66it/s]██▍       | 180/750 [00:50<02:39,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.69it/s]██▍       | 181/750 [00:50<02:37,  3.61it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.57it/s]██▍       | 182/750 [00:50<02:36,  3.64it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.25it/s]██▍       | 183/750 [00:50<02:34,  3.66it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.31it/s]██▍       | 184/750 [00:51<02:34,  3.65it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.24it/s]██▍       | 185/750 [00:51<02:35,  3.64it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.30it/s]██▍       | 186/750 [00:51<02:35,  3.63it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.21it/s]██▍       | 187/750 [00:51<02:38,  3.55it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.70it/s]██▌       | 188/750 [00:52<02:37,  3.57it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.64it/s]██▌       | 189/750 [00:52<02:38,  3.53it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.33it/s]██▌       | 190/750 [00:52<02:36,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.34it/s]██▌       | 191/750 [00:53<02:38,  3.52it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.65it/s]██▌       | 192/750 [00:53<02:40,  3.49it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.28it/s]██▌       | 193/750 [00:53<02:40,  3.47it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.29it/s]██▌       | 194/750 [00:53<02:41,  3.44it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.30it/s]██▌       | 195/750 [00:54<02:42,  3.42it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.26it/s]██▌       | 196/750 [00:54<02:42,  3.40it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.25it/s]██▋       | 197/750 [00:54<02:43,  3.39it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.28it/s]██▋       | 198/750 [00:55<02:44,  3.36it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.24it/s]██▋       | 199/750 [00:55<02:44,  3.35it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.65it/s]██▋       | 200/750 [00:55<02:44,  3.34it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.73it/s]██▋       | 201/750 [00:56<02:43,  3.35it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.73it/s]██▋       | 202/750 [00:56<02:42,  3.38it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.34it/s]██▋       | 203/750 [00:56<02:40,  3.41it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.34it/s]██▋       | 204/750 [00:56<02:37,  3.47it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.33it/s]██▋       | 205/750 [00:57<02:35,  3.50it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.29it/s]██▋       | 206/750 [00:57<02:34,  3.52it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.40it/s]██▊       | 207/750 [00:57<02:31,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.73it/s]██▊       | 208/750 [00:58<02:27,  3.66it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.59it/s]██▊       | 209/750 [00:58<02:24,  3.75it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.35it/s]██▊       | 210/750 [00:58<02:23,  3.78it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.37it/s]██▊       | 211/750 [00:58<02:22,  3.78it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.37it/s]██▊       | 212/750 [00:59<02:24,  3.73it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.48it/s]██▊       | 213/750 [00:59<02:25,  3.69it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.93it/s]██▊       | 214/750 [00:59<02:25,  3.67it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.43it/s]██▊       | 215/750 [00:59<02:25,  3.68it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]██▉       | 216/750 [01:00<02:25,  3.66it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.33it/s]██▉       | 217/750 [01:00<02:26,  3.63it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.49it/s]██▉       | 218/750 [01:00<02:27,  3.61it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.49it/s]██▉       | 219/750 [01:01<02:26,  3.62it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.36it/s]██▉       | 220/750 [01:01<02:26,  3.63it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.40it/s]██▉       | 221/750 [01:01<02:25,  3.64it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.43it/s]██▉       | 222/750 [01:01<02:25,  3.64it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.40it/s]██▉       | 223/750 [01:02<02:25,  3.63it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.37it/s]██▉       | 224/750 [01:02<02:24,  3.65it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.39it/s]███       | 225/750 [01:02<02:24,  3.63it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.50it/s]███       | 226/750 [01:02<02:24,  3.63it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.42it/s]███       | 227/750 [01:03<02:23,  3.64it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.38it/s]███       | 228/750 [01:03<02:22,  3.65it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.38it/s]███       | 229/750 [01:03<02:23,  3.64it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.31it/s]███       | 230/750 [01:04<02:22,  3.64it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.38it/s]███       | 231/750 [01:04<02:22,  3.65it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.33it/s]███       | 232/750 [01:04<02:21,  3.65it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.41it/s]███       | 233/750 [01:04<02:22,  3.63it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.42it/s]███       | 234/750 [01:05<02:21,  3.63it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.40it/s]███▏      | 235/750 [01:05<02:21,  3.64it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.39it/s]███▏      | 236/750 [01:05<02:21,  3.64it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.39it/s]███▏      | 237/750 [01:05<02:21,  3.63it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.62it/s]███▏      | 238/750 [01:06<02:18,  3.69it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.70it/s]███▏      | 239/750 [01:06<02:18,  3.70it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.56it/s]███▏      | 240/750 [01:06<02:17,  3.71it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.67it/s]███▏      | 241/750 [01:07<02:20,  3.62it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.71it/s]███▏      | 242/750 [01:07<02:22,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.64it/s]███▏      | 243/750 [01:07<02:23,  3.53it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.72it/s]███▎      | 244/750 [01:07<02:24,  3.51it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.71it/s]███▎      | 245/750 [01:08<02:24,  3.50it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.68it/s]███▎      | 246/750 [01:08<02:24,  3.48it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.68it/s]███▎      | 247/750 [01:08<02:25,  3.46it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.69it/s]███▎      | 248/750 [01:09<02:24,  3.47it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# ...
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.27it/s]████████▉ | 669/750 [03:04<00:21,  3.72it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.19it/s]████████▉ | 670/750 [03:05<00:21,  3.74it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.06it/s]████████▉ | 671/750 [03:05<00:21,  3.76it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.28it/s]████████▉ | 672/750 [03:05<00:20,  3.74it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.23it/s]████████▉ | 673/750 [03:05<00:20,  3.77it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.27it/s]████████▉ | 674/750 [03:06<00:20,  3.78it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  7.97it/s]█████████ | 675/750 [03:06<00:19,  3.79it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.22it/s]█████████ | 676/750 [03:06<00:19,  3.73it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.26it/s]█████████ | 677/750 [03:07<00:19,  3.74it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.27it/s]█████████ | 678/750 [03:07<00:19,  3.76it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.08it/s]█████████ | 679/750 [03:07<00:18,  3.77it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.22it/s]█████████ | 680/750 [03:07<00:18,  3.77it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.05it/s]█████████ | 681/750 [03:08<00:18,  3.78it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.16it/s]█████████ | 682/750 [03:08<00:17,  3.78it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.26it/s]█████████ | 683/750 [03:08<00:18,  3.71it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.23it/s]█████████ | 684/750 [03:08<00:18,  3.64it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.33it/s]█████████▏| 685/750 [03:09<00:18,  3.61it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.23it/s]█████████▏| 686/750 [03:09<00:17,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.34it/s]█████████▏| 687/750 [03:09<00:17,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.36it/s]█████████▏| 688/750 [03:10<00:17,  3.57it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.31it/s]█████████▏| 689/750 [03:10<00:17,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.29it/s]█████████▏| 690/750 [03:10<00:16,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.02it/s]█████████▏| 691/750 [03:10<00:16,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.15it/s]█████████▏| 692/750 [03:11<00:15,  3.63it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.07it/s]█████████▏| 693/750 [03:11<00:15,  3.66it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.11it/s]█████████▎| 694/750 [03:11<00:15,  3.68it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.22it/s]█████████▎| 695/750 [03:11<00:15,  3.63it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.34it/s]█████████▎| 696/750 [03:12<00:14,  3.61it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.37it/s]█████████▎| 697/750 [03:12<00:14,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.26it/s]█████████▎| 698/750 [03:12<00:14,  3.61it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.22it/s]█████████▎| 699/750 [03:13<00:14,  3.61it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.18it/s]█████████▎| 700/750 [03:13<00:13,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.28it/s]█████████▎| 701/750 [03:13<00:13,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.24it/s]█████████▎| 702/750 [03:13<00:13,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.27it/s]█████████▎| 703/750 [03:14<00:13,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.36it/s]█████████▍| 704/750 [03:14<00:12,  3.62it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.28it/s]█████████▍| 705/750 [03:14<00:12,  3.63it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.25it/s]█████████▍| 706/750 [03:14<00:12,  3.63it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.15it/s]█████████▍| 707/750 [03:15<00:11,  3.62it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.03it/s]█████████▍| 708/750 [03:15<00:11,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.33it/s]█████████▍| 709/750 [03:15<00:11,  3.57it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.29it/s]█████████▍| 710/750 [03:16<00:11,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.25it/s]█████████▍| 711/750 [03:16<00:10,  3.57it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.77it/s]█████████▍| 712/750 [03:16<00:10,  3.58it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.96it/s]█████████▌| 713/750 [03:16<00:10,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.07it/s]█████████▌| 714/750 [03:17<00:09,  3.63it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.26it/s]█████████▌| 715/750 [03:17<00:09,  3.66it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.17it/s]█████████▌| 716/750 [03:17<00:09,  3.63it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.30it/s]█████████▌| 717/750 [03:18<00:09,  3.60it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.08it/s]█████████▌| 718/750 [03:18<00:08,  3.59it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.02it/s]█████████▌| 719/750 [03:18<00:08,  3.64it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.13it/s]█████████▌| 720/750 [03:18<00:08,  3.67it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.64it/s]█████████▌| 721/750 [03:19<00:07,  3.69it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.55it/s]█████████▋| 722/750 [03:19<00:07,  3.74it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.51it/s]█████████▋| 723/750 [03:19<00:07,  3.76it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.05it/s]█████████▋| 724/750 [03:19<00:06,  3.77it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.00it/s]█████████▋| 725/750 [03:20<00:06,  3.77it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.37it/s]█████████▋| 726/750 [03:20<00:06,  3.74it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.07it/s]█████████▋| 727/750 [03:20<00:06,  3.76it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.04it/s]█████████▋| 728/750 [03:20<00:05,  3.75it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.99it/s]█████████▋| 729/750 [03:21<00:05,  3.73it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.03it/s]█████████▋| 730/750 [03:21<00:05,  3.73it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.98it/s]█████████▋| 731/750 [03:21<00:05,  3.72it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.91it/s]█████████▊| 732/750 [03:22<00:04,  3.70it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.11it/s]█████████▊| 733/750 [03:22<00:04,  3.69it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.02it/s]█████████▊| 734/750 [03:22<00:04,  3.70it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.04it/s]█████████▊| 735/750 [03:22<00:04,  3.69it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.06it/s]█████████▊| 736/750 [03:23<00:03,  3.68it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.25it/s]█████████▊| 737/750 [03:23<00:03,  3.68it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.74it/s]█████████▊| 738/750 [03:23<00:03,  3.64it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.23it/s]█████████▊| 739/750 [03:23<00:02,  3.70it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.98it/s]█████████▊| 740/750 [03:24<00:02,  3.65it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.03it/s]█████████▉| 741/750 [03:24<00:02,  3.67it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.94it/s]█████████▉| 742/750 [03:24<00:02,  3.68it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.06it/s]█████████▉| 743/750 [03:25<00:01,  3.69it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.32it/s]█████████▉| 744/750 [03:25<00:01,  3.69it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.56it/s]█████████▉| 745/750 [03:25<00:01,  3.72it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.56it/s]█████████▉| 746/750 [03:25<00:01,  3.75it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.13it/s]█████████▉| 747/750 [03:26<00:00,  3.77it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  9.03it/s]█████████▉| 748/750 [03:26<00:00,  3.76it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Embedding extraction: 1it [00:00,  8.87it/s]█████████▉| 749/750 [03:26<00:00,  3.75it/s]
# FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# Tracking with BoT-SORT (botsort.yaml): 100%|██████████| 750/750 [03:26<00:00,  3.62it/s]
# Finished processing. Annotated video saved to: 0bfacc_0_ultralytics_botsort_tracked_2.mp4

# %% [markdown]
# ## Tracking Method 3 wih BotSort + Paddle OCR

# %%
import supervision as sv
from tqdm import tqdm
import numpy as np
import cv2
from pathlib import Path
import torch
from ultralytics import YOLO
from paddleocr import PaddleOCR, draw_ocr # Import PaddleOCR
import re # For parsing OCR results
import time # For basic profiling/timing

# ----- Configuration -----
SOURCE_VIDEO_PATH = "app/test_data/raw/0bfacc_0.mp4" # Your input video
OUTPUT_VIDEO_PATH = "0bfacc_0_persistent_tracked.mp4" # Output video path
YOLO_MODEL_PATH = "app/models/yolo11_football_v2/weights/best.pt" # Path to your trained YOLO model or a standard one
TRACKER_CONFIG = "botsort.yaml" # BoT-SORT config (Ultralytics usually finds defaults)

# --- Device Setup ---
device = torch.device(0) if torch.cuda.is_available() else torch.device('cpu')
print(f"Using device: {device}")

# --- Class IDs (from your YOLO model's training) ---
BALL_ID = 0
GOALKEEPER_ID = 1
PLAYER_ID = 2
REFEREE_ID = 3

# --- Class IDs for Annotation (after team classification) ---
TEAM_A_ID = 0 # Example ID for Team A
TEAM_B_ID = 1 # Example ID for Team B
ANNOTATION_REFEREE_ID = 2 # Example ID for Referees

# --- OCR Configuration ---
OCR_CONFIDENCE_THRESHOLD = 0.5 # Minimum confidence for accepting OCR number (adjust!)
OCR_USE_GPU = False # torch.cuda.is_available() Use GPU for OCR if available

# --- State Management Configuration ---
MAX_ABSENCE_FRAMES = int(30) # Frames after which a lost player state is considered stale (e.g., 30fps * 1 sec)

# ----- Initialize Models -----

# Load YOLO Model
print(f"Loading YOLO model from: {YOLO_MODEL_PATH}")
model = YOLO(YOLO_MODEL_PATH)
model.to(device)

# Initialize PaddleOCR
# Download models automatically on first run. Specify 'lang='en'' for English numbers.
print("Initializing PaddleOCR...")
# Consider using `rec_model_dir` and `det_model_dir` with specific downloaded models for efficiency/consistency
# Use `use_angle_cls=False` if numbers are mostly upright
ocr_model = PaddleOCR(use_angle_cls=False, lang='en', use_gpu=OCR_USE_GPU, show_log=False)
print("PaddleOCR initialized.")

# ----- Annotators -----
# Colors match annotation IDs: Team A (Blue), Team B (Pink), Referee (Yellow)
palette = sv.ColorPalette.from_hex(['#00BFFF', '#FF1493', '#FFD700'])
ellipse_annotator = sv.EllipseAnnotator(color=palette, thickness=2)
label_annotator = sv.LabelAnnotator(
    color=palette,
    text_color=sv.Color.from_hex('#000000'),
    text_position=sv.Position.BOTTOM_CENTER,
    text_scale=0.6,
    text_thickness=1
)
triangle_annotator = sv.TriangleAnnotator(
    color=sv.Color.from_hex('#32CD32'), # Lime green for ball
    base=25, height=21, outline_thickness=1
)

# ----- Video Processing Setup -----
try:
    video_info = sv.VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
    width, height, fps = video_info.width, video_info.height, video_info.fps
    total_frames = video_info.total_frames or int(fps * 600) # Estimate for long videos if needed
    print(f"Video Info: {width}x{height}, FPS: {fps}, Total Frames: {total_frames}")
    if fps == 0: fps = 30 # Default fps if reading failed
except Exception as e:
    print(f"Error getting video info: {e}. Exiting.")
    exit()

frame_generator = sv.get_video_frames_generator(source_path=SOURCE_VIDEO_PATH, stride=1)
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
video_writer = cv2.VideoWriter(OUTPUT_VIDEO_PATH, fourcc, fps, (width, height))

# ----- State Management Dictionaries -----
# Stores the state for each confirmed real-world player identity
# Key: canonical_id (e.g., "TeamA-10"), Value: dict
player_states = {}
# Maps the current BoT-SORT tracker_id to a confirmed canonical_id
# Key: tracker_id (int), Value: canonical_id (str)
tracker_id_to_canonical = {}

# ----- Helper Function for OCR -----
def run_ocr_on_crop(crop: np.ndarray, ocr_engine: PaddleOCR):
    """
    Runs PaddleOCR on a cropped image and extracts the most likely number.
    Returns (number_str, confidence) or (None, 0.0) if no number found.
    """
    if crop.shape[0] < 10 or crop.shape[1] < 10: # Skip tiny crops
        return None, 0.0

    try:
        # Perform OCR
        ocr_result = ocr_engine.ocr(crop, cls=False, det=True, rec=True) # Use det+rec

        best_num_str = None
        best_confidence = 0.0

        if ocr_result and ocr_result[0]: # Check if results exist
             for line in ocr_result[0]:
                  text, confidence = line[1] # Get text and confidence
                  # Try to find digits in the recognized text
                  numbers = re.findall(r'\d+', text)
                  if numbers:
                       num_str = numbers[0] # Take the first number found
                       if confidence > best_confidence:
                            best_confidence = confidence
                            best_num_str = num_str
                            # print(f"    OCR Found: '{text}' -> Number: {num_str} (Conf: {confidence:.2f})") # Debug

        return best_num_str, best_confidence

    except Exception as e:
        print(f"    Error during OCR: {e}")
        return None, 0.0

# ----- Main Video Processing Loop -----
frame_count = 0
with tqdm(total=total_frames, desc=f"Tracking+OCR") as pbar:
    for frame in frame_generator:
        frame_time_start = time.time()
        frame_count += 1

        # 1. Run YOLOv8 Tracking (BoT-SORT) for people
        results = model.track(
            source=frame,
            persist=True,
            tracker=TRACKER_CONFIG,
            classes=[GOALKEEPER_ID, PLAYER_ID, REFEREE_ID],
            conf=0.3,
            verbose=False,
            device=device
        )

        # 2. Detect Ball Separately
        ball_results = model.predict(frame, classes=[BALL_ID], conf=0.1, verbose=False, device=device)
        ball_detections = sv.Detections.from_ultralytics(ball_results[0])
        if len(ball_detections) > 0:
             ball_detections.xyxy = sv.pad_boxes(xyxy=ball_detections.xyxy, px=10)

        annotated_frame = frame.copy() # Start with original frame for annotation

        # 3. Process Tracking Results & Apply Custom Classification
        detections_for_processing = sv.Detections.empty()
        if results[0].boxes.id is not None:
            tracked_detections = sv.Detections.from_ultralytics(results[0])

            # Separate based on ORIGINAL YOLO ID for classification
            players = tracked_detections[tracked_detections.class_id == PLAYER_ID]
            goalkeepers = tracked_detections[tracked_detections.class_id == GOALKEEPER_ID]
            referees = tracked_detections[tracked_detections.class_id == REFEREE_ID]

            processed_detections_list = []
            
            # Classify Players
            if len(players) > 0:
                player_crops = [sv.crop_image(frame, xyxy) for xyxy in players.xyxy]
                new_player_class_ids = team_classifier.predict(player_crops)
                players.class_id = new_player_class_ids # Overwrite with TEAM_A/B ID
                processed_detections_list.append(players)

            # Classify Goalkeepers
            if len(goalkeepers) > 0:
                new_gk_class_ids = resolve_goalkeepers_team_id(players, goalkeepers)
                goalkeepers.class_id = new_gk_class_ids # Overwrite with TEAM_A/B ID
                processed_detections_list.append(goalkeepers)

            # Assign Referee Annotation ID
            if len(referees) > 0:
                referees.class_id = np.full(len(referees), ANNOTATION_REFEREE_ID)
                processed_detections_list.append(referees)

            # Merge back for OCR and final annotation steps
            if processed_detections_list:
                 detections_for_processing = sv.Detections.merge(processed_detections_list)

        # 4. Persistent ID Logic (State Management + OCR)
        annotation_labels = []
        current_tracker_ids = set()
        if len(detections_for_processing) > 0:
            current_tracker_ids = set(detections_for_processing.tracker_id.astype(int))

            # Mark tracks that disappeared this frame as 'lost' in player_states
            lost_canonical_this_frame = []
            for canonical_id, state in player_states.items():
                if state['current_tracker_id'] is not None and state['current_tracker_id'] not in current_tracker_ids:
                    # print(f"  Track lost for {canonical_id} (tracker_id: {state['current_tracker_id']})")
                    # Remove the potentially stale reverse mapping
                    if state['current_tracker_id'] in tracker_id_to_canonical:
                         if tracker_id_to_canonical[state['current_tracker_id']] == canonical_id:
                              del tracker_id_to_canonical[state['current_tracker_id']]
                    state['current_tracker_id'] = None # Keep state, but mark tracker_id as None
                    lost_canonical_this_frame.append(canonical_id)

            # Process current detections for OCR and state updates
            ocr_time = 0.0
            for i in range(len(detections_for_processing)):
                detection = detections_for_processing[i] # Get individual detection
                tracker_id = int(detection.tracker_id[0]) # Get scalar tracker ID
                bbox = detection.xyxy[0]
                assigned_annotation_class = detection.class_id[0] # Team A/B or Referee ID

                canonical_id_for_this_track = tracker_id_to_canonical.get(tracker_id)
                display_label = f"T:{tracker_id}" # Default label (Use T: prefix)

                ocr_performed = False
                # --- Attempt OCR only for players/GKs ---
                if assigned_annotation_class != ANNOTATION_REFEREE_ID:
                    ocr_start_time = time.time()
                    player_crop = sv.crop_image(annotated_frame, bbox) # Crop from copy
                    number, ocr_confidence = run_ocr_on_crop(player_crop, ocr_model)
                    ocr_time += (time.time() - ocr_start_time)
                    ocr_performed = True

                    if number is not None and ocr_confidence > OCR_CONFIDENCE_THRESHOLD:
                        team_prefix = "A" if assigned_annotation_class == TEAM_A_ID else "B"
                        canonical_id_ocr = f"{team_prefix}{number}" # Compact ID e.g., A10, B7

                        # --- State Update Logic ---
                        # If this tracker ID was previously mapped differently, remove old mapping
                        if tracker_id in tracker_id_to_canonical and tracker_id_to_canonical[tracker_id] != canonical_id_ocr:
                            # print(f"    Conflict: Tracker {tracker_id} mapping changed from {tracker_id_to_canonical[tracker_id]} to {canonical_id_ocr}")
                            # Mark the OLD canonical ID as potentially lost if it's not associated with another tracker
                            old_canonical = tracker_id_to_canonical[tracker_id]
                            if old_canonical in player_states and player_states[old_canonical]['current_tracker_id'] == tracker_id:
                                 player_states[old_canonical]['current_tracker_id'] = None
                            # Remove old mapping before adding new one
                            del tracker_id_to_canonical[tracker_id]


                        # Update/Create player state
                        if canonical_id_ocr not in player_states:
                            player_states[canonical_id_ocr] = {'current_tracker_id': None, 'last_seen_frame': -1, 'last_bbox': None, 'ocr_confidence': 0.0}

                        player_states[canonical_id_ocr].update({
                            'current_tracker_id': tracker_id,
                            'last_seen_frame': frame_count,
                            'last_bbox': bbox,
                            'ocr_confidence': ocr_confidence
                        })
                        tracker_id_to_canonical[tracker_id] = canonical_id_ocr
                        canonical_id_for_this_track = canonical_id_ocr
                        display_label = canonical_id_ocr # Use the confirmed ID

                    # --- End State Update ---

                # --- Update display label and state if association already exists ---
                if canonical_id_for_this_track:
                    display_label = canonical_id_for_this_track # Use existing if OCR failed/low conf
                    # Update last seen frame/bbox for existing association
                    if canonical_id_for_this_track in player_states:
                         player_states[canonical_id_for_this_track]['last_seen_frame'] = frame_count
                         player_states[canonical_id_for_this_track]['last_bbox'] = bbox
                         # Ensure the current tracker ID is correctly linked, especially if it was lost and found
                         player_states[canonical_id_for_this_track]['current_tracker_id'] = tracker_id
                         # Also update the reverse map just in case
                         tracker_id_to_canonical[tracker_id] = canonical_id_for_this_track
                # else: # No OCR success and no existing association
                     # display_label remains the default "T:{tracker_id}"

                annotation_labels.append(display_label)
            # print(f"  OCR time for frame: {ocr_time:.4f}s") # Optional timing

        # 5. Clean up stale player states (optional, can be done less frequently)
        if frame_count % (fps * 10) == 0: # Every 10 seconds
             stale_ids = [
                  cid for cid, state in player_states.items()
                  if state['current_tracker_id'] is None and (frame_count - state['last_seen_frame']) > MAX_ABSENCE_FRAMES
             ]
             for cid in stale_ids:
                  print(f"  Removing stale state for {cid}")
                  del player_states[cid]
                  # Clean up reverse map if any stale tracker ID points to it
                  stale_tracker_id = None
                  for tid, mapped_cid in tracker_id_to_canonical.items():
                       if mapped_cid == cid:
                            stale_tracker_id = tid
                            break
                  if stale_tracker_id:
                       del tracker_id_to_canonical[stale_tracker_id]


        # 6. Annotation
        # Annotate tracked people (using team/role class for color, canonical ID for label)
        if len(detections_for_processing) > 0:
            annotated_frame = ellipse_annotator.annotate(
                scene=annotated_frame,
                detections=detections_for_processing # Ellipse color based on Team A/B/Ref ID
            )
            annotated_frame = label_annotator.annotate(
                scene=annotated_frame,
                detections=detections_for_processing,
                labels=annotation_labels # Label text is Canonical ID or T:tracker_id
            )

        # Annotate ball
        if len(ball_detections) > 0:
            annotated_frame = triangle_annotator.annotate(
                scene=annotated_frame,
                detections=ball_detections
            )

        # 7. Write Frame
        video_writer.write(annotated_frame)
        pbar.update(1)
        frame_time_end = time.time()
        # print(f"Frame {frame_count} processing time: {frame_time_end - frame_time_start:.4f}s") # Optional timing

# Release resources
video_writer.release()
print(f"Finished processing. Annotated video saved to: {OUTPUT_VIDEO_PATH}")
print("\nFinal Player States:")
for cid, state in player_states.items():
    print(f"  {cid}: Last Seen Frame={state['last_seen_frame']}, Current TrackerID={state['current_tracker_id']}")
# Out:
# Using device: cuda:0
# Loading YOLO model from: app/models/yolo11_football_v2/weights/best.pt
# Initializing PaddleOCR...
# PaddleOCR initialized.
# Video Info: 1920x1080, FPS: 25, Total Frames: 750
# Embedding extraction: 1it [00:00,  8.49it/s]?, ?it/s]
# Embedding extraction: 1it [00:00,  8.44it/s]10:46,  1.16it/s]
# Embedding extraction: 1it [00:00,  8.51it/s]06:56,  1.80it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]05:45,  2.16it/s]
# Embedding extraction: 1it [00:00,  8.51it/s]05:12,  2.39it/s]
# Embedding extraction: 1it [00:00,  8.43it/s]04:52,  2.54it/s]
# Embedding extraction: 1it [00:00,  8.48it/s]04:45,  2.60it/s]
# Embedding extraction: 1it [00:00,  8.55it/s]04:35,  2.69it/s]
# Embedding extraction: 1it [00:00,  8.50it/s]04:49,  2.57it/s]
# Embedding extraction: 1it [00:00,  8.60it/s]04:38,  2.66it/s]
# Embedding extraction: 1it [00:00,  8.63it/s]<04:29,  2.74it/s]
# Embedding extraction: 1it [00:00,  9.43it/s]<04:23,  2.80it/s]
# Embedding extraction: 1it [00:00,  9.64it/s]<04:15,  2.89it/s]
# Embedding extraction: 1it [00:00,  8.58it/s]<04:16,  2.88it/s]
# Embedding extraction: 1it [00:00,  9.27it/s]<04:19,  2.83it/s]
# Embedding extraction: 1it [00:00,  9.07it/s]<04:14,  2.89it/s]
# Embedding extraction: 1it [00:00,  8.29it/s]<04:20,  2.81it/s]
# Embedding extraction: 1it [00:00,  9.28it/s]<04:26,  2.75it/s]
# Embedding extraction: 1it [00:00,  9.08it/s]<04:29,  2.71it/s]
# Embedding extraction: 1it [00:00,  8.59it/s]<04:28,  2.73it/s]
# Embedding extraction: 1it [00:00,  9.39it/s]<04:31,  2.69it/s]
# Embedding extraction: 1it [00:00,  8.52it/s]<04:31,  2.68it/s]
# Embedding extraction: 1it [00:00,  8.51it/s]<04:40,  2.59it/s]
# Embedding extraction: 1it [00:00,  8.63it/s]<04:40,  2.60it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]<04:45,  2.54it/s]
# Embedding extraction: 1it [00:00,  8.54it/s]<04:57,  2.43it/s]
# Embedding extraction: 1it [00:00,  8.52it/s]<04:59,  2.42it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]<05:01,  2.39it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]<05:01,  2.39it/s]
# Embedding extraction: 1it [00:00,  8.76it/s]<04:57,  2.42it/s]
# Embedding extraction: 1it [00:00,  8.55it/s]<04:52,  2.46it/s]
# Embedding extraction: 1it [00:00,  8.47it/s]<04:54,  2.44it/s]
# Embedding extraction: 1it [00:00,  9.43it/s]<04:49,  2.48it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]<04:44,  2.52it/s]
# Embedding extraction: 1it [00:00,  8.51it/s]<04:35,  2.60it/s]
# Embedding extraction: 1it [00:00,  9.13it/s]<04:35,  2.60it/s]
# Embedding extraction: 1it [00:00,  9.42it/s]<04:41,  2.54it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]<04:50,  2.46it/s]
# Embedding extraction: 1it [00:00,  8.97it/s]<04:46,  2.48it/s]
# Embedding extraction: 1it [00:00,  8.45it/s]<04:42,  2.52it/s]
# Embedding extraction: 1it [00:00,  7.80it/s]<04:37,  2.56it/s]
# Embedding extraction: 1it [00:00,  8.01it/s]<04:30,  2.63it/s]
# Embedding extraction: 1it [00:00,  7.76it/s]<04:44,  2.49it/s]
# Embedding extraction: 1it [00:00,  8.68it/s]<04:42,  2.50it/s]
# Embedding extraction: 1it [00:00,  7.87it/s]<04:40,  2.51it/s]
# Embedding extraction: 1it [00:00,  8.64it/s]<04:49,  2.44it/s]
# Embedding extraction: 1it [00:00,  8.54it/s]<04:46,  2.46it/s]
# Embedding extraction: 1it [00:00,  8.56it/s]<04:36,  2.54it/s]
# Embedding extraction: 1it [00:00,  8.48it/s]<04:35,  2.55it/s]
# Embedding extraction: 1it [00:00,  8.45it/s]<04:29,  2.60it/s]
# Embedding extraction: 1it [00:00,  8.64it/s]<04:24,  2.65it/s]
# Embedding extraction: 1it [00:00,  8.56it/s]<04:15,  2.74it/s]
# Embedding extraction: 1it [00:00,  9.40it/s]<04:09,  2.80it/s]
# Embedding extraction: 1it [00:00,  8.65it/s]<04:03,  2.86it/s]
# Embedding extraction: 1it [00:00,  9.41it/s]<04:02,  2.87it/s]
# Embedding extraction: 1it [00:00,  9.37it/s]<04:15,  2.72it/s]
# Embedding extraction: 1it [00:00,  9.39it/s]<04:26,  2.60it/s]
# Embedding extraction: 1it [00:00,  9.51it/s]<04:38,  2.49it/s]
# Embedding extraction: 1it [00:00,  8.44it/s]<04:34,  2.52it/s]
# Embedding extraction: 1it [00:00,  8.57it/s]<04:36,  2.50it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]<04:34,  2.51it/s]
# Embedding extraction: 1it [00:00,  8.46it/s]<04:39,  2.47it/s]
# Embedding extraction: 1it [00:00,  8.52it/s]<04:43,  2.43it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]<04:32,  2.52it/s]
# Embedding extraction: 1it [00:00,  8.45it/s]<04:25,  2.58it/s]
# Embedding extraction: 1it [00:00,  8.51it/s]<04:20,  2.63it/s]
# Embedding extraction: 1it [00:00,  8.45it/s]<04:15,  2.68it/s]
# Embedding extraction: 1it [00:00,  8.51it/s]<04:19,  2.63it/s]
# Embedding extraction: 1it [00:00,  8.47it/s]<04:18,  2.64it/s]
# Embedding extraction: 1it [00:00,  8.48it/s]<04:21,  2.61it/s]
# Embedding extraction: 1it [00:00,  8.46it/s]<04:16,  2.65it/s]
# Embedding extraction: 1it [00:00,  8.59it/s]<04:25,  2.56it/s]
# Embedding extraction: 1it [00:00,  7.76it/s]<04:32,  2.49it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]<04:46,  2.37it/s]
# Embedding extraction: 1it [00:00,  8.50it/s]<04:40,  2.41it/s]
# Embedding extraction: 1it [00:00,  8.51it/s]<04:41,  2.40it/s]
# Embedding extraction: 1it [00:00,  8.34it/s]<05:16,  2.13it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]<05:07,  2.19it/s]
# Embedding extraction: 1it [00:00,  8.43it/s]<05:00,  2.23it/s]
# Embedding extraction: 1it [00:00,  8.42it/s]<04:56,  2.27it/s]
# Embedding extraction: 1it [00:00,  8.46it/s]<04:47,  2.33it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]<04:46,  2.33it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]<04:39,  2.39it/s]
# Embedding extraction: 1it [00:00,  8.44it/s]<04:34,  2.43it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]<04:30,  2.46it/s]
# Embedding extraction: 1it [00:00,  8.44it/s]<04:27,  2.49it/s]
# Embedding extraction: 1it [00:00,  8.36it/s]<04:24,  2.51it/s]
# Embedding extraction: 1it [00:00,  8.35it/s]<04:17,  2.58it/s]
# Embedding extraction: 1it [00:00,  8.50it/s]<04:18,  2.57it/s]
# Embedding extraction: 1it [00:00,  8.51it/s]<04:18,  2.55it/s]
# Embedding extraction: 1it [00:00,  8.28it/s]<04:25,  2.48it/s]
# Embedding extraction: 1it [00:00,  8.46it/s]<04:30,  2.44it/s]
# Embedding extraction: 1it [00:00,  8.42it/s]<04:20,  2.52it/s]
# Embedding extraction: 1it [00:00,  8.35it/s]<04:22,  2.50it/s]
# Embedding extraction: 1it [00:00,  7.69it/s]<04:17,  2.54it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]<04:17,  2.55it/s]
# Embedding extraction: 1it [00:00,  8.44it/s]<04:20,  2.51it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]<04:16,  2.55it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]<04:13,  2.58it/s]
# Embedding extraction: 1it [00:00,  8.48it/s]<04:05,  2.65it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]9<04:09,  2.61it/s]
# Embedding extraction: 1it [00:00,  8.48it/s]9<04:05,  2.65it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]0<04:03,  2.67it/s]
# Embedding extraction: 1it [00:00,  8.54it/s]0<04:00,  2.69it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]1<04:04,  2.64it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]1<04:07,  2.60it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]1<04:04,  2.64it/s]
# Embedding extraction: 1it [00:00,  7.81it/s]2<04:06,  2.61it/s]
# Embedding extraction: 1it [00:00,  7.81it/s]2<04:05,  2.61it/s]
# Embedding extraction: 1it [00:00,  7.82it/s]3<04:20,  2.46it/s]
# Embedding extraction: 1it [00:00,  8.44it/s]3<04:27,  2.39it/s]
# Embedding extraction: 1it [00:00,  8.54it/s]3<04:23,  2.42it/s]
# Embedding extraction: 1it [00:00,  7.76it/s]4<04:13,  2.51it/s]
# Embedding extraction: 1it [00:00,  7.79it/s]4<04:10,  2.55it/s]
# Embedding extraction: 1it [00:00,  8.46it/s]5<04:13,  2.51it/s]
# Embedding extraction: 1it [00:00,  8.37it/s]5<04:12,  2.52it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]5<04:11,  2.52it/s]
# Embedding extraction: 1it [00:00,  8.42it/s]6<04:16,  2.46it/s]
# Embedding extraction: 1it [00:00,  8.45it/s]6<04:20,  2.42it/s]
# Embedding extraction: 1it [00:00,  8.48it/s]7<04:10,  2.51it/s]
# Embedding extraction: 1it [00:00,  8.42it/s]7<04:09,  2.52it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]7<04:08,  2.53it/s]
# Embedding extraction: 1it [00:00,  8.72it/s]8<04:02,  2.60it/s]
# Embedding extraction: 1it [00:00,  8.58it/s]8<04:02,  2.59it/s]
# Embedding extraction: 1it [00:00,  8.46it/s]8<03:57,  2.64it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]9<03:54,  2.67it/s]
# Embedding extraction: 1it [00:00,  8.47it/s]9<03:52,  2.69it/s]
# Embedding extraction: 1it [00:00,  8.34it/s]0<03:55,  2.64it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]0<03:56,  2.63it/s]
# Embedding extraction: 1it [00:00,  8.43it/s]0<04:01,  2.57it/s]
# Embedding extraction: 1it [00:00,  8.44it/s]1<04:00,  2.58it/s]
# Embedding extraction: 1it [00:00,  8.48it/s]1<04:01,  2.56it/s]
# Embedding extraction: 1it [00:00,  8.46it/s]2<04:07,  2.50it/s]
# Embedding extraction: 1it [00:00,  8.25it/s]2<04:05,  2.52it/s]
# Embedding extraction: 1it [00:00,  8.46it/s]2<04:12,  2.44it/s]
# Embedding extraction: 1it [00:00,  8.42it/s]3<04:20,  2.36it/s]
# Embedding extraction: 1it [00:00,  8.48it/s]3<04:20,  2.36it/s]
# Embedding extraction: 1it [00:00,  8.43it/s]4<04:21,  2.35it/s]
# Embedding extraction: 1it [00:00,  8.51it/s]4<04:09,  2.45it/s]
# Embedding extraction: 1it [00:00,  8.47it/s]4<04:00,  2.54it/s]
# Embedding extraction: 1it [00:00,  8.42it/s]5<04:00,  2.54it/s]
# Embedding extraction: 1it [00:00,  8.46it/s]5<03:54,  2.60it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]6<03:50,  2.64it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]6<03:52,  2.61it/s]
# Embedding extraction: 1it [00:00,  8.48it/s]6<04:00,  2.52it/s]
# Embedding extraction: 1it [00:00,  8.47it/s]7<04:11,  2.41it/s]
# Embedding extraction: 1it [00:00,  8.55it/s]7<04:03,  2.48it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]8<03:58,  2.53it/s]
# Embedding extraction: 1it [00:00,  7.67it/s]8<03:54,  2.57it/s]
# Embedding extraction: 1it [00:00,  7.32it/s]8<03:49,  2.62it/s]
# Embedding extraction: 1it [00:00,  7.46it/s]9<03:56,  2.54it/s]
# Embedding extraction: 1it [00:00,  7.36it/s]9<03:57,  2.52it/s]
# Embedding extraction: 1it [00:00,  7.79it/s]0<03:52,  2.57it/s]
# Embedding extraction: 1it [00:00,  7.41it/s]0<03:48,  2.62it/s]
# Embedding extraction: 1it [00:00,  7.30it/s]0<03:46,  2.64it/s]
# Embedding extraction: 1it [00:00,  7.35it/s]1<03:44,  2.65it/s]
# Embedding extraction: 1it [00:00,  7.77it/s]1<03:42,  2.67it/s]
# Embedding extraction: 1it [00:00,  7.75it/s]1<03:41,  2.68it/s]
# Embedding extraction: 1it [00:00,  7.78it/s]2<03:39,  2.70it/s]
# Embedding extraction: 1it [00:00,  7.72it/s]2<03:40,  2.68it/s]
# Embedding extraction: 1it [00:00,  7.77it/s]2<03:41,  2.67it/s]
# Embedding extraction: 1it [00:00,  7.78it/s]3<03:47,  2.59it/s]
# Embedding extraction: 1it [00:00,  7.79it/s]3<03:51,  2.54it/s]
# Embedding extraction: 1it [00:00,  8.36it/s]4<03:53,  2.51it/s]
# Embedding extraction: 1it [00:00,  7.77it/s]4<03:47,  2.57it/s]
# Embedding extraction: 1it [00:00,  7.77it/s]5<03:55,  2.48it/s]
# Embedding extraction: 1it [00:00,  7.73it/s]5<04:01,  2.41it/s]
# Embedding extraction: 1it [00:00,  8.32it/s]5<03:52,  2.51it/s]
# Embedding extraction: 1it [00:00,  7.75it/s]6<03:51,  2.51it/s]
# Embedding extraction: 1it [00:00,  7.75it/s]6<03:53,  2.49it/s]
# Embedding extraction: 1it [00:00,  7.77it/s]7<03:48,  2.54it/s]
# Embedding extraction: 1it [00:00,  7.75it/s]7<03:50,  2.51it/s]
# Embedding extraction: 1it [00:00,  7.76it/s]7<03:45,  2.56it/s]
# Embedding extraction: 1it [00:00,  7.83it/s]8<03:40,  2.62it/s]
# Embedding extraction: 1it [00:00,  7.76it/s]8<03:38,  2.63it/s]
# Embedding extraction: 1it [00:00,  7.79it/s]8<03:37,  2.64it/s]
# Embedding extraction: 1it [00:00,  7.72it/s]9<03:36,  2.65it/s]
# Embedding extraction: 1it [00:00,  7.72it/s]9<03:35,  2.66it/s]
# Embedding extraction: 1it [00:00,  7.77it/s]0<03:32,  2.70it/s]
# Embedding extraction: 1it [00:00,  7.80it/s]0<03:29,  2.72it/s]
# Embedding extraction: 1it [00:00,  7.73it/s]0<03:31,  2.70it/s]
# Embedding extraction: 1it [00:00,  7.79it/s]1<03:28,  2.72it/s]
# Embedding extraction: 1it [00:00,  7.67it/s]1<03:32,  2.67it/s]
# Embedding extraction: 1it [00:00,  7.30it/s]1<03:35,  2.64it/s]
# Embedding extraction: 1it [00:00,  7.29it/s]2<03:33,  2.65it/s]
# Embedding extraction: 1it [00:00,  7.31it/s]2<03:31,  2.67it/s]
# Embedding extraction: 1it [00:00,  7.31it/s]3<03:30,  2.67it/s]
# Embedding extraction: 1it [00:00,  7.40it/s]3<03:32,  2.65it/s]
# Embedding extraction: 1it [00:00,  7.81it/s]3<03:35,  2.61it/s]
# Embedding extraction: 1it [00:00,  7.69it/s]4<03:44,  2.50it/s]
# Embedding extraction: 1it [00:00,  7.30it/s]4<03:43,  2.51it/s]
# Embedding extraction: 1it [00:00,  7.33it/s]5<03:40,  2.53it/s]
# Embedding extraction: 1it [00:00,  7.77it/s]5<03:50,  2.42it/s]
# Embedding extraction: 1it [00:00,  7.35it/s]5<03:49,  2.43it/s]
# Embedding extraction: 1it [00:00,  7.28it/s]6<03:46,  2.46it/s]
# Embedding extraction: 1it [00:00,  7.26it/s]6<03:53,  2.38it/s]
# Embedding extraction: 1it [00:00,  7.31it/s]7<03:48,  2.43it/s]
# Embedding extraction: 1it [00:00,  7.33it/s]7<03:54,  2.36it/s]
# Embedding extraction: 1it [00:00,  7.27it/s]7<03:48,  2.41it/s]
# Embedding extraction: 1it [00:00,  7.30it/s]8<03:49,  2.40it/s]
# Embedding extraction: 1it [00:00,  7.75it/s]8<03:50,  2.39it/s]
# Embedding extraction: 1it [00:00,  7.82it/s]9<03:49,  2.39it/s]
# Embedding extraction: 1it [00:00,  7.75it/s]9<03:43,  2.45it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]9<03:37,  2.51it/s]
# Embedding extraction: 1it [00:00,  8.50it/s]0<03:36,  2.52it/s]
# Embedding extraction: 1it [00:00,  8.35it/s]0<03:31,  2.58it/s]
# Embedding extraction: 1it [00:00,  8.45it/s]1<03:27,  2.62it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]1<03:26,  2.63it/s]
# Embedding extraction: 1it [00:00,  8.46it/s]1<03:25,  2.64it/s]
# Embedding extraction: 1it [00:00,  8.53it/s]2<03:19,  2.71it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]2<03:19,  2.71it/s]
# Embedding extraction: 1it [00:00,  8.42it/s]2<03:15,  2.76it/s]
# Embedding extraction: 1it [00:00,  8.36it/s]3<03:14,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.36it/s]3<03:12,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.51it/s]4<03:18,  2.70it/s]
# Embedding extraction: 1it [00:00,  8.44it/s]4<03:21,  2.66it/s]
# Embedding extraction: 1it [00:00,  8.35it/s]4<03:24,  2.61it/s]
# Embedding extraction: 1it [00:00,  8.46it/s]5<03:20,  2.65it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]5<03:22,  2.62it/s]
# Embedding extraction: 1it [00:00,  8.56it/s]5<03:23,  2.60it/s]
# Embedding extraction: 1it [00:00,  8.42it/s]6<03:19,  2.66it/s]
# Embedding extraction: 1it [00:00,  8.50it/s]6<03:16,  2.69it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]7<03:19,  2.65it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]7<03:16,  2.69it/s]
# Embedding extraction: 1it [00:00,  8.43it/s]7<03:14,  2.71it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]8<03:17,  2.65it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]8<03:15,  2.67it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]8<03:18,  2.64it/s]
# Embedding extraction: 1it [00:00,  8.32it/s]9<03:19,  2.62it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]9<03:16,  2.65it/s]
# Embedding extraction: 1it [00:00,  8.35it/s]0<03:12,  2.70it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]0<03:20,  2.59it/s]
# Embedding extraction: 1it [00:00,  8.42it/s]0<03:20,  2.58it/s]
# Embedding extraction: 1it [00:00,  8.45it/s]1<03:16,  2.64it/s]
# Embedding extraction: 1it [00:00,  8.43it/s]1<03:12,  2.68it/s]
# Embedding extraction: 1it [00:00,  8.47it/s]1<03:09,  2.72it/s]
# Embedding extraction: 1it [00:00,  8.37it/s]2<03:07,  2.74it/s]
# Embedding extraction: 1it [00:00,  8.46it/s]2<03:06,  2.75it/s]
# Embedding extraction: 1it [00:00,  7.72it/s]3<03:08,  2.72it/s]
# Embedding extraction: 1it [00:00,  7.74it/s]3<03:05,  2.75it/s]
# Embedding extraction: 1it [00:00,  7.75it/s]3<03:09,  2.70it/s]
# Embedding extraction: 1it [00:00,  7.79it/s]4<03:09,  2.69it/s]
# Embedding extraction: 1it [00:00,  7.75it/s]4<03:09,  2.68it/s]
# Embedding extraction: 1it [00:00,  7.67it/s]4<03:09,  2.68it/s]
# Embedding extraction: 1it [00:00,  7.76it/s]5<03:10,  2.66it/s]
# Embedding extraction: 1it [00:00,  7.72it/s]5<03:15,  2.59it/s]
# Embedding extraction: 1it [00:00,  7.77it/s]6<03:13,  2.61it/s]
# Embedding extraction: 1it [00:00,  7.67it/s]6<03:11,  2.62it/s]
# Embedding extraction: 1it [00:00,  7.74it/s]6<03:15,  2.57it/s]
# Embedding extraction: 1it [00:00,  7.66it/s]7<03:18,  2.53it/s]
# Tracking+OCR:  33%|███▎      | 250/750 [01:37<03:19,  2.50it/s]
#   Removing stale state for A3
# Embedding extraction: 1it [00:00,  7.72it/s]
# Embedding extraction: 1it [00:00,  7.76it/s]8<03:25,  2.43it/s]
# Embedding extraction: 1it [00:00,  7.71it/s]8<03:20,  2.48it/s]
# Embedding extraction: 1it [00:00,  7.79it/s]8<03:16,  2.53it/s]
# Embedding extraction: 1it [00:00,  7.75it/s]9<03:13,  2.57it/s]
# Embedding extraction: 1it [00:00,  7.72it/s]9<03:10,  2.59it/s]
# Embedding extraction: 1it [00:00,  8.35it/s]0<03:09,  2.61it/s]
# Embedding extraction: 1it [00:00,  7.71it/s]0<03:05,  2.65it/s]
# Embedding extraction: 1it [00:00,  7.78it/s]0<03:05,  2.65it/s]
# Embedding extraction: 1it [00:00,  7.67it/s]1<03:05,  2.64it/s]
# Embedding extraction: 1it [00:00,  7.65it/s]1<03:05,  2.64it/s]
# Embedding extraction: 1it [00:00,  7.68it/s]1<03:05,  2.64it/s]
# Embedding extraction: 1it [00:00,  8.48it/s]2<03:07,  2.61it/s]
# Embedding extraction: 1it [00:00,  7.74it/s]2<03:04,  2.64it/s]
# Embedding extraction: 1it [00:00,  7.80it/s]3<03:01,  2.68it/s]
# Embedding extraction: 1it [00:00,  7.72it/s]3<03:01,  2.67it/s]
# Embedding extraction: 1it [00:00,  7.75it/s]3<03:01,  2.67it/s]
# Embedding extraction: 1it [00:00,  7.71it/s]4<03:00,  2.67it/s]
# Embedding extraction: 1it [00:00,  7.73it/s]4<03:00,  2.66it/s]
# Embedding extraction: 1it [00:00,  7.72it/s]4<03:00,  2.66it/s]
# Embedding extraction: 1it [00:00,  7.71it/s]5<02:58,  2.69it/s]
# Embedding extraction: 1it [00:00,  7.75it/s]5<03:00,  2.65it/s]
# Embedding extraction: 1it [00:00,  7.69it/s]6<02:58,  2.68it/s]
# Embedding extraction: 1it [00:00,  7.76it/s]6<02:55,  2.71it/s]
# Embedding extraction: 1it [00:00,  7.65it/s]6<02:54,  2.73it/s]
# Embedding extraction: 1it [00:00,  7.70it/s]7<02:53,  2.74it/s]
# Embedding extraction: 1it [00:00,  7.67it/s]7<02:52,  2.75it/s]
# Embedding extraction: 1it [00:00,  7.72it/s]7<02:51,  2.76it/s]
# Embedding extraction: 1it [00:00,  7.74it/s]8<02:50,  2.77it/s]
# Embedding extraction: 1it [00:00,  7.71it/s]8<02:50,  2.77it/s]
# Embedding extraction: 1it [00:00,  7.68it/s]8<02:49,  2.77it/s]
# Embedding extraction: 1it [00:00,  7.63it/s]9<02:49,  2.77it/s]
# Embedding extraction: 1it [00:00,  7.71it/s]9<02:48,  2.78it/s]
# Embedding extraction: 1it [00:00,  7.79it/s]9<02:47,  2.78it/s]
# Embedding extraction: 1it [00:00,  7.65it/s]0<02:47,  2.78it/s]
# Embedding extraction: 1it [00:00,  7.67it/s]0<02:46,  2.78it/s]
# Embedding extraction: 1it [00:00,  7.70it/s]1<02:46,  2.78it/s]
# Embedding extraction: 1it [00:00,  7.68it/s]1<02:46,  2.78it/s]
# Embedding extraction: 1it [00:00,  7.72it/s]1<02:47,  2.77it/s]
# Embedding extraction: 1it [00:00,  7.69it/s]2<02:46,  2.77it/s]
# Embedding extraction: 1it [00:00,  7.70it/s]2<02:50,  2.70it/s]
# Embedding extraction: 1it [00:00,  7.73it/s]2<02:48,  2.73it/s]
# Embedding extraction: 1it [00:00,  7.70it/s]3<02:46,  2.75it/s]
# Embedding extraction: 1it [00:00,  7.72it/s]3<02:45,  2.76it/s]
# Embedding extraction: 1it [00:00,  8.01it/s]3<02:45,  2.76it/s]
# Embedding extraction: 1it [00:00,  7.72it/s]4<02:50,  2.67it/s]
# Embedding extraction: 1it [00:00,  7.73it/s]4<02:55,  2.59it/s]
# Embedding extraction: 1it [00:00,  8.67it/s]5<02:54,  2.60it/s]
# Embedding extraction: 1it [00:00,  7.70it/s]5<02:50,  2.64it/s]
# Embedding extraction: 1it [00:00,  7.78it/s]5<02:50,  2.64it/s]
# Embedding extraction: 1it [00:00,  8.54it/s]6<02:50,  2.64it/s]
# Embedding extraction: 1it [00:00,  7.64it/s]6<02:47,  2.68it/s]
# Embedding extraction: 1it [00:00,  7.71it/s]7<02:48,  2.67it/s]
# Embedding extraction: 1it [00:00,  9.28it/s]7<02:48,  2.65it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]7<02:44,  2.71it/s]
# Embedding extraction: 1it [00:00,  8.56it/s]8<02:43,  2.72it/s]
# Embedding extraction: 1it [00:00,  7.97it/s]8<02:40,  2.77it/s]
# Embedding extraction: 1it [00:00,  7.71it/s]8<02:43,  2.71it/s]
# Embedding extraction: 1it [00:00,  8.67it/s]9<02:43,  2.70it/s]
# Embedding extraction: 1it [00:00,  7.72it/s]9<02:41,  2.72it/s]
# Embedding extraction: 1it [00:00,  7.77it/s]9<02:42,  2.70it/s]
# Embedding extraction: 1it [00:00,  7.66it/s]0<02:47,  2.62it/s]
# Embedding extraction: 1it [00:00,  7.72it/s]0<02:46,  2.63it/s]
# Embedding extraction: 1it [00:00,  7.69it/s]1<02:46,  2.63it/s]
# Embedding extraction: 1it [00:00,  7.69it/s]1<02:47,  2.60it/s]
# Embedding extraction: 1it [00:00,  7.69it/s]1<02:52,  2.52it/s]
# Embedding extraction: 1it [00:00,  7.69it/s]2<02:47,  2.59it/s]
# Embedding extraction: 1it [00:00,  7.74it/s]2<02:43,  2.64it/s]
# Embedding extraction: 1it [00:00,  7.73it/s]3<02:40,  2.69it/s]
# Embedding extraction: 1it [00:00,  7.69it/s]3<02:39,  2.71it/s]
# Embedding extraction: 1it [00:00,  7.80it/s]3<02:39,  2.69it/s]
# Embedding extraction: 1it [00:00,  7.73it/s]4<02:43,  2.62it/s]
# Embedding extraction: 1it [00:00,  7.74it/s]4<02:42,  2.63it/s]
# Embedding extraction: 1it [00:00,  7.73it/s]4<02:41,  2.64it/s]
# Embedding extraction: 1it [00:00,  7.71it/s]5<02:41,  2.64it/s]
# Embedding extraction: 1it [00:00,  7.77it/s]5<02:47,  2.53it/s]
# Embedding extraction: 1it [00:00,  7.73it/s]6<02:52,  2.46it/s]
# Embedding extraction: 1it [00:00,  7.31it/s]6<02:50,  2.48it/s]
# Embedding extraction: 1it [00:00,  7.31it/s]6<02:46,  2.54it/s]
# Embedding extraction: 1it [00:00,  7.26it/s]7<02:42,  2.59it/s]
# Embedding extraction: 1it [00:00,  7.29it/s]7<02:40,  2.61it/s]
# Embedding extraction: 1it [00:00,  7.72it/s]8<02:38,  2.64it/s]
# Embedding extraction: 1it [00:00,  7.74it/s]8<02:35,  2.68it/s]
# Embedding extraction: 1it [00:00,  7.77it/s]8<02:35,  2.68it/s]
# Embedding extraction: 1it [00:00,  7.75it/s]9<02:35,  2.68it/s]
# Embedding extraction: 1it [00:00,  7.66it/s]9<02:32,  2.73it/s]
# Embedding extraction: 1it [00:00,  7.80it/s]9<02:30,  2.75it/s]
# Embedding extraction: 1it [00:00,  7.80it/s]0<02:31,  2.72it/s]
# Embedding extraction: 1it [00:00,  7.79it/s]0<02:29,  2.75it/s]
# Embedding extraction: 1it [00:00,  7.84it/s]0<02:31,  2.72it/s]
# Embedding extraction: 1it [00:00,  7.73it/s]1<02:31,  2.70it/s]
# Embedding extraction: 1it [00:00,  7.73it/s]1<02:29,  2.74it/s]
# Embedding extraction: 1it [00:00,  7.77it/s]2<02:30,  2.71it/s]
# Embedding extraction: 1it [00:00,  7.36it/s]2<02:35,  2.61it/s]
# Embedding extraction: 1it [00:00,  7.29it/s]2<02:36,  2.60it/s]
# Embedding extraction: 1it [00:00,  7.80it/s]3<02:36,  2.59it/s]
# Embedding extraction: 1it [00:00,  7.75it/s]3<02:34,  2.62it/s]
# Embedding extraction: 1it [00:00,  7.74it/s]4<02:36,  2.57it/s]
# Embedding extraction: 1it [00:00,  7.75it/s]4<02:41,  2.49it/s]
# Embedding extraction: 1it [00:00,  7.78it/s]4<02:46,  2.40it/s]
# Embedding extraction: 1it [00:00,  7.24it/s]5<02:42,  2.46it/s]
# Embedding extraction: 1it [00:00,  7.73it/s]5<02:44,  2.42it/s]
# Embedding extraction: 1it [00:00,  7.76it/s]6<02:39,  2.49it/s]
# Embedding extraction: 1it [00:00,  7.74it/s]6<02:36,  2.53it/s]
# Embedding extraction: 1it [00:00,  7.70it/s]6<02:34,  2.56it/s]
# Embedding extraction: 1it [00:00,  7.77it/s]7<02:33,  2.57it/s]
# Embedding extraction: 1it [00:00,  7.74it/s]7<02:33,  2.57it/s]
# Embedding extraction: 1it [00:00,  7.68it/s]8<02:32,  2.58it/s]
# Embedding extraction: 1it [00:00,  7.69it/s]8<02:31,  2.59it/s]
# Embedding extraction: 1it [00:00,  7.74it/s]8<02:32,  2.57it/s]
# Embedding extraction: 1it [00:00,  7.79it/s]9<02:28,  2.62it/s]
# Embedding extraction: 1it [00:00,  7.72it/s]9<02:25,  2.67it/s]
# Embedding extraction: 1it [00:00,  7.74it/s]9<02:23,  2.70it/s]
# Embedding extraction: 1it [00:00,  7.72it/s]0<02:22,  2.72it/s]
# Embedding extraction: 1it [00:00,  7.78it/s]0<02:20,  2.74it/s]
# Embedding extraction: 1it [00:00,  7.78it/s]0<02:20,  2.75it/s]
# Embedding extraction: 1it [00:00,  7.78it/s]1<02:19,  2.76it/s]
# Embedding extraction: 1it [00:00,  7.95it/s]1<02:18,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.69it/s]2<02:17,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.91it/s]2<02:15,  2.80it/s]
# Embedding extraction: 1it [00:00,  9.06it/s]2<02:13,  2.84it/s]
# Embedding extraction: 1it [00:00,  8.45it/s]3<02:12,  2.87it/s]
# Embedding extraction: 1it [00:00,  8.61it/s]3<02:11,  2.88it/s]
# Embedding extraction: 1it [00:00,  8.55it/s]3<02:10,  2.90it/s]
# Embedding extraction: 1it [00:00,  8.48it/s]4<02:09,  2.91it/s]
# Embedding extraction: 1it [00:00,  8.51it/s]4<02:08,  2.92it/s]
# Embedding extraction: 1it [00:00,  8.99it/s]4<02:07,  2.92it/s]
# Embedding extraction: 1it [00:00,  9.21it/s]5<02:06,  2.94it/s]
# Embedding extraction: 1it [00:00,  8.51it/s]5<02:06,  2.94it/s]
# Embedding extraction: 1it [00:00,  8.35it/s]5<02:06,  2.94it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]6<02:06,  2.92it/s]
# Embedding extraction: 1it [00:00,  9.36it/s]6<02:10,  2.83it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]6<02:14,  2.73it/s]
# Embedding extraction: 1it [00:00,  8.47it/s]7<02:20,  2.62it/s]
# Embedding extraction: 1it [00:00,  8.63it/s]7<02:18,  2.65it/s]
# Embedding extraction: 1it [00:00,  8.71it/s]8<02:14,  2.72it/s]
# Embedding extraction: 1it [00:00,  8.47it/s]8<02:10,  2.78it/s]
# Embedding extraction: 1it [00:00,  9.36it/s]8<02:12,  2.73it/s]
# Embedding extraction: 1it [00:00,  8.70it/s]9<02:08,  2.81it/s]
# Embedding extraction: 1it [00:00,  8.42it/s]9<02:07,  2.84it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]9<02:06,  2.86it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]0<02:05,  2.87it/s]
# Embedding extraction: 1it [00:00,  8.46it/s]0<02:04,  2.88it/s]
# Embedding extraction: 1it [00:00,  8.37it/s]0<02:03,  2.89it/s]
# Embedding extraction: 1it [00:00,  8.37it/s]1<02:03,  2.88it/s]
# Embedding extraction: 1it [00:00,  8.44it/s]1<02:04,  2.85it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]1<02:05,  2.82it/s]
# Embedding extraction: 1it [00:00,  8.46it/s]2<02:04,  2.85it/s]
# Embedding extraction: 1it [00:00,  8.06it/s]2<02:02,  2.86it/s]
# Embedding extraction: 1it [00:00,  8.37it/s]2<02:02,  2.87it/s]
# Embedding extraction: 1it [00:00,  8.45it/s]3<02:03,  2.84it/s]
# Embedding extraction: 1it [00:00,  9.28it/s]3<02:03,  2.82it/s]
# Embedding extraction: 1it [00:00,  8.43it/s]3<02:01,  2.86it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]4<02:00,  2.88it/s]
# Embedding extraction: 1it [00:00,  8.65it/s]4<02:00,  2.88it/s]
# Embedding extraction: 1it [00:00,  9.25it/s]5<02:00,  2.85it/s]
# Embedding extraction: 1it [00:00,  8.42it/s]5<02:00,  2.85it/s]
# Embedding extraction: 1it [00:00,  9.18it/s]5<01:59,  2.87it/s]
# Embedding extraction: 1it [00:00,  8.32it/s]6<02:01,  2.82it/s]
# Embedding extraction: 1it [00:00,  8.52it/s]6<02:05,  2.72it/s]
# Embedding extraction: 1it [00:00,  8.37it/s]6<02:07,  2.66it/s]
# Embedding extraction: 1it [00:00,  9.32it/s]7<02:08,  2.64it/s]
# Embedding extraction: 1it [00:00,  8.58it/s]7<02:05,  2.70it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]7<02:03,  2.72it/s]
# Embedding extraction: 1it [00:00,  8.71it/s]8<02:06,  2.66it/s]
# Embedding extraction: 1it [00:00,  8.69it/s]8<02:03,  2.71it/s]
# Embedding extraction: 1it [00:00,  9.29it/s]9<02:02,  2.73it/s]
# Embedding extraction: 1it [00:00,  8.44it/s]9<02:00,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.44it/s]9<02:02,  2.70it/s]
# Embedding extraction: 1it [00:00,  8.46it/s]0<02:01,  2.72it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]0<02:02,  2.70it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]0<02:03,  2.66it/s]
# Embedding extraction: 1it [00:00,  8.53it/s]1<02:03,  2.66it/s]
# Embedding extraction: 1it [00:00,  8.50it/s]1<02:01,  2.69it/s]
# Embedding extraction: 1it [00:00,  8.43it/s]2<02:00,  2.71it/s]
# Embedding extraction: 1it [00:00,  8.37it/s]2<01:59,  2.72it/s]
# Embedding extraction: 1it [00:00,  8.43it/s]2<01:58,  2.74it/s]
# Embedding extraction: 1it [00:00,  8.47it/s]3<01:57,  2.75it/s]
# Embedding extraction: 1it [00:00,  8.36it/s]3<01:56,  2.76it/s]
# Embedding extraction: 1it [00:00,  8.35it/s]3<01:56,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.47it/s]4<01:56,  2.76it/s]
# Embedding extraction: 1it [00:00,  8.42it/s]4<01:56,  2.75it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]4<01:55,  2.74it/s]
# Embedding extraction: 1it [00:00,  8.45it/s]5<01:55,  2.75it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]5<01:54,  2.76it/s]
# Embedding extraction: 1it [00:00,  8.54it/s]6<01:54,  2.76it/s]
# Embedding extraction: 1it [00:00,  8.45it/s]6<01:53,  2.75it/s]
# Embedding extraction: 1it [00:00,  8.42it/s]6<01:53,  2.76it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]7<01:51,  2.80it/s]
# Embedding extraction: 1it [00:00,  9.07it/s]7<01:51,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]7<01:51,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.42it/s]8<01:51,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.45it/s]8<01:51,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.62it/s]8<01:50,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]9<01:50,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]9<01:49,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.43it/s]0<01:49,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.36it/s]0<01:52,  2.70it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]0<01:51,  2.71it/s]
# Embedding extraction: 1it [00:00,  8.44it/s]1<01:48,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.42it/s]1<01:47,  2.80it/s]
# Embedding extraction: 1it [00:00,  8.37it/s]1<01:45,  2.83it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]2<01:45,  2.81it/s]
# Embedding extraction: 1it [00:00,  8.47it/s]2<01:46,  2.80it/s]
# Embedding extraction: 1it [00:00,  8.42it/s]2<01:46,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.47it/s]3<01:46,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.46it/s]3<01:46,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]3<01:45,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.54it/s]4<01:45,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.67it/s]4<01:44,  2.77it/s]
# Embedding extraction: 1it [00:00,  9.33it/s]5<01:44,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.67it/s]5<01:42,  2.81it/s]
# Embedding extraction: 1it [00:00,  8.64it/s]5<01:48,  2.66it/s]
# Embedding extraction: 1it [00:00,  8.93it/s]6<01:51,  2.57it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]6<01:51,  2.57it/s]
# Embedding extraction: 1it [00:00,  9.36it/s]7<01:50,  2.57it/s]
# Embedding extraction: 1it [00:00,  8.36it/s]7<01:49,  2.58it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]7<01:52,  2.52it/s]
# Embedding extraction: 1it [00:00,  8.34it/s]8<01:51,  2.52it/s]
# Embedding extraction: 1it [00:00,  8.34it/s]8<01:48,  2.59it/s]
# Embedding extraction: 1it [00:00,  9.29it/s]8<01:48,  2.58it/s]
# Embedding extraction: 1it [00:00,  8.82it/s]9<01:44,  2.66it/s]
# Embedding extraction: 1it [00:00,  8.74it/s]9<01:42,  2.70it/s]
# Embedding extraction: 1it [00:00,  7.86it/s]0<01:39,  2.77it/s]
# Embedding extraction: 1it [00:00,  7.75it/s]0<01:39,  2.78it/s]
# Embedding extraction: 1it [00:00,  7.94it/s]0<01:38,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.52it/s]1<01:37,  2.80it/s]
# Embedding extraction: 1it [00:00,  7.53it/s]1<01:36,  2.82it/s]
# Embedding extraction: 1it [00:00,  7.28it/s]1<01:37,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.31it/s]2<01:37,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.44it/s]2<01:36,  2.80it/s]
# Embedding extraction: 1it [00:00,  7.76it/s]2<01:36,  2.80it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]3<01:37,  2.75it/s]
# Embedding extraction: 1it [00:00,  8.35it/s]3<01:35,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.44it/s]3<01:35,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]4<01:36,  2.75it/s]
# Embedding extraction: 1it [00:00,  8.35it/s]4<01:34,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.44it/s]5<01:33,  2.83it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]5<01:33,  2.81it/s]
# Embedding extraction: 1it [00:00,  8.45it/s]5<01:33,  2.80it/s]
# Embedding extraction: 1it [00:00,  8.44it/s]6<01:33,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]6<01:32,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.44it/s]6<01:32,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]7<01:32,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.17it/s]7<01:32,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.15it/s]7<01:31,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.33it/s]8<01:32,  2.76it/s]
# Embedding extraction: 1it [00:00,  7.71it/s]8<01:31,  2.75it/s]
# Embedding extraction: 1it [00:00,  8.36it/s]9<01:31,  2.76it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]9<01:31,  2.76it/s]
# Tracking+OCR:  67%|██████▋   | 500/750 [03:09<01:30,  2.76it/s]
#   Removing stale state for A12
#   Removing stale state for A72
# Embedding extraction: 1it [00:00,  8.63it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]0<01:32,  2.70it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]0<01:35,  2.58it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]0<01:33,  2.64it/s]
# Embedding extraction: 1it [00:00,  8.37it/s]1<01:31,  2.67it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]1<01:30,  2.70it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]2<01:30,  2.69it/s]
# Embedding extraction: 1it [00:00,  8.35it/s]2<01:29,  2.72it/s]
# Embedding extraction: 1it [00:00,  8.48it/s]2<01:30,  2.67it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]3<01:28,  2.72it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]3<01:28,  2.72it/s]
# Embedding extraction: 1it [00:00,  8.28it/s]3<01:27,  2.73it/s]
# Embedding extraction: 1it [00:00,  8.28it/s]4<01:28,  2.70it/s]
# Embedding extraction: 1it [00:00,  8.36it/s]4<01:28,  2.68it/s]
# Embedding extraction: 1it [00:00,  8.33it/s]4<01:26,  2.74it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]5<01:24,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.46it/s]5<01:22,  2.82it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]5<01:21,  2.85it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]6<01:23,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]6<01:24,  2.74it/s]
# Embedding extraction: 1it [00:00,  8.42it/s]7<01:27,  2.63it/s]
# Embedding extraction: 1it [00:00,  8.42it/s]7<01:26,  2.64it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]7<01:28,  2.58it/s]
# Embedding extraction: 1it [00:00,  9.30it/s]8<01:27,  2.59it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]8<01:26,  2.62it/s]
# Embedding extraction: 1it [00:00,  8.29it/s]9<01:23,  2.70it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]9<01:23,  2.67it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]9<01:24,  2.65it/s]
# Embedding extraction: 1it [00:00,  8.46it/s]0<01:21,  2.72it/s]
# Embedding extraction: 1it [00:00,  8.35it/s]0<01:24,  2.61it/s]
# Embedding extraction: 1it [00:00,  8.37it/s]0<01:22,  2.68it/s]
# Embedding extraction: 1it [00:00,  8.36it/s]1<01:20,  2.73it/s]
# Embedding extraction: 1it [00:00,  8.32it/s]1<01:18,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.47it/s]1<01:19,  2.73it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]2<01:17,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]2<01:16,  2.82it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]3<01:18,  2.73it/s]
# Embedding extraction: 1it [00:00,  8.36it/s]3<01:18,  2.73it/s]
# Embedding extraction: 1it [00:00,  8.32it/s]3<01:18,  2.70it/s]
# Embedding extraction: 1it [00:00,  8.43it/s]4<01:16,  2.75it/s]
# Embedding extraction: 1it [00:00,  8.43it/s]4<01:16,  2.75it/s]
# Embedding extraction: 1it [00:00,  8.33it/s]4<01:14,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.35it/s]5<01:13,  2.82it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]5<01:12,  2.84it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]5<01:12,  2.85it/s]
# Embedding extraction: 1it [00:00,  8.54it/s]6<01:11,  2.86it/s]
# Embedding extraction: 1it [00:00,  8.36it/s]6<01:11,  2.86it/s]
# Embedding extraction: 1it [00:00,  8.36it/s]6<01:10,  2.86it/s]
# Embedding extraction: 1it [00:00,  7.71it/s]7<01:10,  2.87it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]7<01:10,  2.84it/s]
# Embedding extraction: 1it [00:00,  8.33it/s]8<01:09,  2.86it/s]
# Embedding extraction: 1it [00:00,  8.45it/s]8<01:09,  2.86it/s]
# Embedding extraction: 1it [00:00,  8.34it/s]8<01:09,  2.86it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]9<01:08,  2.86it/s]
# Embedding extraction: 1it [00:00,  8.35it/s]9<01:08,  2.86it/s]
# Embedding extraction: 1it [00:00,  8.37it/s]9<01:07,  2.87it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]0<01:07,  2.87it/s]
# Embedding extraction: 1it [00:00,  8.34it/s]0<01:07,  2.86it/s]
# Embedding extraction: 1it [00:00,  8.37it/s]0<01:08,  2.82it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]1<01:07,  2.85it/s]
# Embedding extraction: 1it [00:00,  8.37it/s]1<01:06,  2.86it/s]
# Embedding extraction: 1it [00:00,  8.29it/s]1<01:05,  2.87it/s]
# Embedding extraction: 1it [00:00,  8.46it/s]2<01:05,  2.87it/s]
# Embedding extraction: 1it [00:00,  8.37it/s]2<01:04,  2.88it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]2<01:04,  2.89it/s]
# Embedding extraction: 1it [00:00,  8.35it/s]3<01:03,  2.90it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]3<01:04,  2.84it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]3<01:04,  2.82it/s]
# Embedding extraction: 1it [00:00,  8.42it/s]4<01:04,  2.82it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]4<01:03,  2.84it/s]
# Embedding extraction: 1it [00:00,  8.50it/s]5<01:02,  2.86it/s]
# Embedding extraction: 1it [00:00,  8.34it/s]5<01:03,  2.84it/s]
# Embedding extraction: 1it [00:00,  8.59it/s]5<01:02,  2.86it/s]
# Embedding extraction: 1it [00:00,  8.32it/s]6<01:02,  2.84it/s]
# Embedding extraction: 1it [00:00,  8.28it/s]6<01:01,  2.85it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]6<01:01,  2.87it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]7<01:00,  2.87it/s]
# Embedding extraction: 1it [00:00,  8.30it/s]7<01:00,  2.88it/s]
# Embedding extraction: 1it [00:00,  8.30it/s]7<00:59,  2.88it/s]
# Embedding extraction: 1it [00:00,  8.34it/s]8<00:59,  2.89it/s]
# Embedding extraction: 1it [00:00,  8.32it/s]8<00:58,  2.89it/s]
# Embedding extraction: 1it [00:00,  8.26it/s]8<00:59,  2.85it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]9<00:58,  2.85it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]9<00:58,  2.86it/s]
# Embedding extraction: 1it [00:00,  8.55it/s]9<00:58,  2.83it/s]
# Embedding extraction: 1it [00:00,  9.16it/s]0<00:58,  2.81it/s]
# Embedding extraction: 1it [00:00,  8.33it/s]0<00:58,  2.81it/s]
# Embedding extraction: 1it [00:00,  8.36it/s]0<00:58,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]1<00:58,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]1<00:57,  2.81it/s]
# Embedding extraction: 1it [00:00,  8.29it/s]2<00:56,  2.83it/s]
# Embedding extraction: 1it [00:00,  8.31it/s]2<00:56,  2.84it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]2<00:56,  2.81it/s]
# Embedding extraction: 1it [00:00,  8.45it/s]3<00:56,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.30it/s]3<00:56,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.30it/s]3<00:56,  2.76it/s]
# Embedding extraction: 1it [00:00,  8.29it/s]4<00:55,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]4<00:55,  2.76it/s]
# Embedding extraction: 1it [00:00,  8.27it/s]4<00:55,  2.75it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]5<00:55,  2.74it/s]
# Embedding extraction: 1it [00:00,  8.21it/s]5<00:54,  2.75it/s]
# Embedding extraction: 1it [00:00,  8.34it/s]6<00:54,  2.74it/s]
# Embedding extraction: 1it [00:00,  8.31it/s]6<00:53,  2.74it/s]
# Embedding extraction: 1it [00:00,  8.29it/s]6<00:53,  2.75it/s]
# Embedding extraction: 1it [00:00,  8.34it/s]7<00:52,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.28it/s]7<00:52,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]7<00:51,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]8<00:51,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.31it/s]8<00:51,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.31it/s]8<00:50,  2.80it/s]
# Embedding extraction: 1it [00:00,  8.27it/s]9<00:50,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]9<00:49,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.60it/s]9<00:49,  2.80it/s]
# Embedding extraction: 1it [00:00,  8.33it/s]0<00:48,  2.80it/s]
# Embedding extraction: 1it [00:00,  8.30it/s]0<00:48,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]1<00:49,  2.74it/s]
# Embedding extraction: 1it [00:00,  8.48it/s]1<00:48,  2.75it/s]
# Embedding extraction: 1it [00:00,  8.45it/s]1<00:48,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.34it/s]2<00:47,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.56it/s]2<00:47,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.30it/s]2<00:46,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.37it/s]3<00:45,  2.81it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]3<00:45,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.28it/s]3<00:45,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]4<00:45,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]4<00:45,  2.76it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]5<00:44,  2.76it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]5<00:44,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.33it/s]5<00:44,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.37it/s]6<00:43,  2.76it/s]
# Embedding extraction: 1it [00:00,  8.34it/s]6<00:43,  2.75it/s]
# Embedding extraction: 1it [00:00,  8.33it/s]6<00:42,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.33it/s]7<00:41,  2.81it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]7<00:41,  2.82it/s]
# Embedding extraction: 1it [00:00,  8.36it/s]7<00:41,  2.76it/s]
# Embedding extraction: 1it [00:00,  8.29it/s]8<00:41,  2.76it/s]
# Embedding extraction: 1it [00:00,  8.29it/s]8<00:42,  2.68it/s]
# Embedding extraction: 1it [00:00,  8.26it/s]9<00:42,  2.69it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]9<00:41,  2.70it/s]
# Embedding extraction: 1it [00:00,  8.26it/s]9<00:41,  2.70it/s]
# Embedding extraction: 1it [00:00,  8.30it/s]0<00:40,  2.71it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]0<00:40,  2.72it/s]
# Embedding extraction: 1it [00:00,  8.36it/s]0<00:40,  2.68it/s]
# Embedding extraction: 1it [00:00,  8.32it/s]1<00:40,  2.65it/s]
# Embedding extraction: 1it [00:00,  8.33it/s]1<00:39,  2.67it/s]
# Embedding extraction: 1it [00:00,  8.27it/s]2<00:39,  2.69it/s]
# Embedding extraction: 1it [00:00,  8.28it/s]2<00:38,  2.70it/s]
# Embedding extraction: 1it [00:00,  8.32it/s]2<00:37,  2.72it/s]
# Embedding extraction: 1it [00:00,  8.32it/s]3<00:37,  2.71it/s]
# Embedding extraction: 1it [00:00,  8.34it/s]3<00:38,  2.60it/s]
# Embedding extraction: 1it [00:00,  8.42it/s]3<00:38,  2.62it/s]
# Embedding extraction: 1it [00:00,  7.63it/s]4<00:37,  2.65it/s]
# Embedding extraction: 1it [00:00,  7.59it/s]4<00:36,  2.67it/s]
# Embedding extraction: 1it [00:00,  7.60it/s]5<00:36,  2.65it/s]
# Embedding extraction: 1it [00:00,  7.67it/s]5<00:36,  2.64it/s]
# Embedding extraction: 1it [00:00,  8.32it/s]5<00:36,  2.58it/s]
# Embedding extraction: 1it [00:00,  8.31it/s]6<00:37,  2.53it/s]
# Embedding extraction: 1it [00:00,  7.64it/s]6<00:37,  2.51it/s]
# Embedding extraction: 1it [00:00,  8.36it/s]7<00:38,  2.40it/s]
# Embedding extraction: 1it [00:00,  8.37it/s]7<00:36,  2.52it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]7<00:35,  2.52it/s]
# Embedding extraction: 1it [00:00,  8.29it/s]8<00:34,  2.58it/s]
# Embedding extraction: 1it [00:00,  8.30it/s]8<00:33,  2.59it/s]
# Embedding extraction: 1it [00:00,  8.29it/s]8<00:33,  2.63it/s]
# Embedding extraction: 1it [00:00,  8.31it/s]9<00:32,  2.68it/s]
# Embedding extraction: 1it [00:00,  8.31it/s]9<00:31,  2.74it/s]
# Embedding extraction: 1it [00:00,  8.02it/s]0<00:30,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.33it/s]0<00:29,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.36it/s]0<00:29,  2.82it/s]
# Embedding extraction: 1it [00:00,  8.31it/s]1<00:29,  2.75it/s]
# Embedding extraction: 1it [00:00,  8.30it/s]1<00:28,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.23it/s]1<00:28,  2.80it/s]
# Embedding extraction: 1it [00:00,  8.28it/s]2<00:27,  2.82it/s]
# Embedding extraction: 1it [00:00,  8.26it/s]2<00:27,  2.83it/s]
# Embedding extraction: 1it [00:00,  8.35it/s]2<00:26,  2.84it/s]
# Embedding extraction: 1it [00:00,  8.32it/s]3<00:27,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.30it/s]3<00:27,  2.73it/s]
# Embedding extraction: 1it [00:00,  8.27it/s]3<00:27,  2.70it/s]
# Embedding extraction: 1it [00:00,  8.48it/s]4<00:26,  2.68it/s]
# Embedding extraction: 1it [00:00,  8.42it/s]4<00:26,  2.69it/s]
# Embedding extraction: 1it [00:00,  8.33it/s]5<00:25,  2.75it/s]
# Embedding extraction: 1it [00:00,  8.24it/s]5<00:24,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.30it/s]5<00:24,  2.80it/s]
# Embedding extraction: 1it [00:00,  8.33it/s]6<00:23,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.36it/s]6<00:23,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.27it/s]6<00:23,  2.76it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]7<00:23,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.22it/s]7<00:22,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.39it/s]7<00:22,  2.76it/s]
# Embedding extraction: 1it [00:00,  8.43it/s]8<00:21,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.35it/s]8<00:21,  2.77it/s]
# Embedding extraction: 1it [00:00,  9.16it/s]9<00:21,  2.77it/s]
# Embedding extraction: 1it [00:00,  9.12it/s]9<00:21,  2.75it/s]
# Embedding extraction: 1it [00:00,  9.17it/s]9<00:20,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]0<00:19,  2.82it/s]
# Embedding extraction: 1it [00:00,  8.34it/s]0<00:19,  2.82it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]0<00:19,  2.81it/s]
# Embedding extraction: 1it [00:00,  8.34it/s]1<00:18,  2.81it/s]
# Embedding extraction: 1it [00:00,  8.27it/s]1<00:19,  2.74it/s]
# Embedding extraction: 1it [00:00,  8.45it/s]1<00:18,  2.76it/s]
# Embedding extraction: 1it [00:00,  8.43it/s]2<00:18,  2.77it/s]
# Embedding extraction: 1it [00:00,  8.44it/s]2<00:17,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.36it/s]2<00:17,  2.80it/s]
# Embedding extraction: 1it [00:00,  8.45it/s]3<00:16,  2.81it/s]
# Embedding extraction: 1it [00:00,  8.41it/s]3<00:16,  2.82it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]4<00:16,  2.74it/s]
# Embedding extraction: 1it [00:00,  8.49it/s]4<00:15,  2.76it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]4<00:15,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.37it/s]5<00:15,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.33it/s]5<00:14,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.29it/s]5<00:14,  2.79it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]6<00:14,  2.79it/s]
# Embedding extraction: 1it [00:00,  9.14it/s]6<00:13,  2.79it/s]
# Embedding extraction: 1it [00:00,  9.25it/s]6<00:13,  2.82it/s]
# Embedding extraction: 1it [00:00,  9.22it/s]7<00:12,  2.78it/s]
# Embedding extraction: 1it [00:00,  8.40it/s]7<00:12,  2.83it/s]
# Embedding extraction: 1it [00:00,  8.38it/s]7<00:12,  2.81it/s]
# Embedding extraction: 1it [00:00,  8.30it/s]8<00:11,  2.81it/s]
# Embedding extraction: 1it [00:00,  9.26it/s]8<00:11,  2.80it/s]
# Embedding extraction: 1it [00:00,  9.17it/s]9<00:10,  2.82it/s]
# Embedding extraction: 1it [00:00,  9.13it/s]9<00:10,  2.85it/s]
# Embedding extraction: 1it [00:00,  9.66it/s]9<00:10,  2.87it/s]
# Embedding extraction: 1it [00:00,  9.69it/s]0<00:09,  2.92it/s]
# Embedding extraction: 1it [00:00,  9.54it/s]0<00:09,  2.94it/s]
# Embedding extraction: 1it [00:00,  9.20it/s]0<00:09,  2.88it/s]
# Embedding extraction: 1it [00:00,  9.26it/s]1<00:08,  2.89it/s]
# Embedding extraction: 1it [00:00,  9.86it/s]1<00:08,  2.75it/s]
# Embedding extraction: 1it [00:00,  9.12it/s]1<00:08,  2.76it/s]
# Embedding extraction: 1it [00:00,  9.15it/s]2<00:07,  2.80it/s]
# Embedding extraction: 1it [00:00,  9.15it/s]2<00:07,  2.82it/s]
# Embedding extraction: 1it [00:00,  9.15it/s]2<00:07,  2.84it/s]
# Embedding extraction: 1it [00:00,  9.16it/s]3<00:06,  2.78it/s]
# Embedding extraction: 1it [00:00,  9.11it/s]3<00:06,  2.71it/s]
# Embedding extraction: 1it [00:00,  9.25it/s]4<00:06,  2.69it/s]
# Embedding extraction: 1it [00:00,  9.23it/s]4<00:05,  2.71it/s]
# Embedding extraction: 1it [00:00,  9.23it/s]4<00:05,  2.69it/s]
# Embedding extraction: 1it [00:00,  9.18it/s]5<00:05,  2.67it/s]
# Embedding extraction: 1it [00:00,  8.43it/s]5<00:04,  2.62it/s]
# Embedding extraction: 1it [00:00,  9.79it/s]5<00:04,  2.66it/s]
# Embedding extraction: 1it [00:00,  8.32it/s]6<00:03,  2.76it/s]
# Embedding extraction: 1it [00:00,  9.18it/s]6<00:03,  2.69it/s]
# Embedding extraction: 1it [00:00,  9.12it/s]7<00:03,  2.62it/s]
# Embedding extraction: 1it [00:00,  9.22it/s]7<00:03,  2.56it/s]
# Embedding extraction: 1it [00:00,  9.20it/s]7<00:02,  2.59it/s]
# Embedding extraction: 1it [00:00,  9.58it/s]8<00:02,  2.53it/s]
# Embedding extraction: 1it [00:00,  9.56it/s]8<00:01,  2.53it/s]
# Embedding extraction: 1it [00:00,  9.77it/s]9<00:01,  2.58it/s]
# Embedding extraction: 1it [00:00,  9.15it/s]9<00:01,  2.62it/s]
# Embedding extraction: 1it [00:00,  9.19it/s]9<00:00,  2.63it/s]
# Embedding extraction: 1it [00:00,  9.17it/s]0<00:00,  2.71it/s]
# Tracking+OCR: 100%|██████████| 750/750 [04:40<00:00,  2.67it/s]
#   Removing stale state for A1
# Finished processing. Annotated video saved to: 0bfacc_0_persistent_tracked.mp4
#
# Final Player States:
#   A7: Last Seen Frame=750, Current TrackerID=9
#   A2: Last Seen Frame=750, Current TrackerID=8
#   B10: Last Seen Frame=750, Current TrackerID=401
